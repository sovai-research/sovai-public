# %%
# !pip install sovai[full]

# %%
# pip uninstall sovai -y && pip install -e "../.."

# %%
# !pip install /Users/dereksnow/Sovai/GitHub/SovAI/dist/sovai-0.1.13-py3-none-any.whl

# %%
## first just make build for local version

# %%
pip uninstall sovai -y
# Out:
# Found existing installation: sovai 0.2.11
# Uninstalling sovai-0.2.11:
#   Successfully uninstalled sovai-0.2.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install /Users/dereksnow/Sovai/GitHub/SovAI/dist/sovai-0.2.11-py3-none-any.whl
# Out:
# Processing /Users/dereksnow/Sovai/GitHub/SovAI/dist/sovai-0.2.11-py3-none-any.whl
# Requirement already satisfied: boto3>=1.20 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (1.34.149)
# Requirement already satisfied: joblib>=1.0 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (1.4.2)
# Requirement already satisfied: numpy>=1.20 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (1.26.4)
# Requirement already satisfied: pandas>=1.0 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (2.2.2)
# Requirement already satisfied: polars>=0.20.30 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (1.5.0)
# Requirement already satisfied: pyarrow>=5.0 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (17.0.0)
# Requirement already satisfied: python-dateutil>=2.8 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (2.9.0.post0)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (1.0.1)
# Requirement already satisfied: requests>=2.20 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from sovai==0.2.11) (2.32.3)
# Requirement already satisfied: botocore<1.35.0,>=1.34.149 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from boto3>=1.20->sovai==0.2.11) (1.34.149)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from boto3>=1.20->sovai==0.2.11) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from boto3>=1.20->sovai==0.2.11) (0.10.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from pandas>=1.0->sovai==0.2.11) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from pandas>=1.0->sovai==0.2.11) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8->sovai==0.2.11) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from requests>=2.20->sovai==0.2.11) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from requests>=2.20->sovai==0.2.11) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from requests>=2.20->sovai==0.2.11) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dereksnow/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages (from requests>=2.20->sovai==0.2.11) (2024.7.4)
# Installing collected packages: sovai
# Successfully installed sovai-0.2.11
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import sovai as sov

sov.token_auth(token="visit https://sov.ai/profile for your token")

df_breakout = sov.data("breakout")

# %%
df_breakout.get_latest()
# Out:
#         ticker       date  target  future_returns  prediction  \
# 2754943   NBST 2024-08-16   1.000           0.000       0.786
# 1896473   HCVI 2024-08-16   1.000           0.000       0.786
# 2119338   INTE 2024-08-16   1.000           0.000       0.786
# 2178644   IVCP 2024-08-16   1.000           0.000       0.786
# 673968    BRKH 2024-08-16   1.000           0.000       0.785
# ...        ...        ...     ...             ...         ...
# 1555218   FGEN 2024-08-16   1.000           0.000       0.124
# 2740602   NAAS 2024-08-16   1.000           0.000       0.124
# 504307    BCAN 2024-08-16   1.000           0.000       0.124
# 4432632    XBP 2024-08-16   1.000           0.000       0.124
# 1344963   EFSH 2024-08-16   1.000           0.000       0.124
#
#          bottom_prediction  top_prediction  standard_deviation  \
# 2754943              0.691           0.820               0.041
# 1896473              0.691           0.820               0.041
# 2119338              0.691           0.820               0.041
# 2178644              0.691           0.820               0.041
# 673968               0.691           0.818               0.040
# ...                    ...             ...                 ...
# 1555218              0.121           0.127               0.002
# 2740602              0.121           0.127               0.002
# 504307               0.121           0.127               0.002
# 4432632              0.121           0.127               0.002
# 1344963              0.121           0.127               0.002
#
#          bottom_conformal  top_conformal  slope
# 2754943             0.360          0.775  0.004
# 1896473             0.360          0.775 -0.000
# 2119338             0.360          0.775 -0.001
# 2178644             0.360          0.775  0.715
# 673968              0.360          0.775  0.108
# ...                   ...            ...    ...
# 1555218             0.000          0.374  0.005
# 2740602             0.000          0.374 -0.016
# 504307              0.000          0.374 -0.001
# 4432632             0.000          0.374 -0.001
# 1344963             0.000          0.374 -0.002
#
# [5832 rows x 11 columns]

# %%
df_breakout.query("ticker =='AAPL'")
# Out:
#       ticker       date  target  future_returns  prediction  \
# 10898   AAPL 2021-05-11   1.000           0.158       0.162
# 10899   AAPL 2021-05-12   1.000           0.185       0.162
# 10900   AAPL 2021-05-13   1.000           0.179       0.162
# 10901   AAPL 2021-05-14   1.000           0.153       0.163
# 10902   AAPL 2021-05-17   1.000           0.165       0.162
# ...      ...        ...     ...             ...         ...
# 11701   AAPL 2024-07-22   0.000          -0.027       0.321
# 11702   AAPL 2024-07-23   0.000          -0.031       0.313
# 11703   AAPL 2024-07-24   0.000          -0.003       0.313
# 11704   AAPL 2024-07-25   1.000           0.002       0.310
# 11705   AAPL 2024-07-26   1.000           0.000       0.309
#
#        bottom_prediction  top_prediction  standard_deviation  \
# 10898              0.153           0.169               0.006
# 10899              0.152           0.169               0.007
# 10900              0.151           0.169               0.007
# 10901              0.152           0.170               0.007
# 10902              0.151           0.170               0.007
# ...                  ...             ...                 ...
# 11701              0.313           0.330               0.007
# 11702              0.301           0.320               0.007
# 11703              0.299           0.320               0.007
# 11704              0.297           0.318               0.007
# 11705              0.295           0.318               0.007
#
#        bottom_conformal  top_conformal  slope
# 10898             0.000          0.383 -0.241
# 10899             0.000          0.383 -0.238
# 10900             0.000          0.383 -0.233
# 10901             0.000          0.383 -0.228
# 10902             0.000          0.383 -0.222
# ...                 ...            ...    ...
# 11701             0.066          0.480 -0.127
# 11702             0.061          0.474 -0.125
# 11703             0.060          0.474 -0.124
# 11704             0.060          0.474 -0.118
# 11705             0.060          0.474 -0.107
#
# [808 rows x 11 columns]
