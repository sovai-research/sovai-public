# %%
# !pip install sovai[full]

# %% [markdown]
# You probably have to force this to run once a week or something and push the file.

# %%
import pandas as pd
tick = pd.read_parquet("https://storage.googleapis.com/sovai-public/accounting/tickers_transformed.parq")

# %%
tick
# Out:
#       table  permaticker ticker                                  name  \
# 0       SF1       196290      A              AGILENT TECHNOLOGIES INC
# 1       SF1       124392     AA                            ALCOA CORP
# 2       SF1       122827   AAAB                 ADMIRALTY BANCORP INC
# 3       SF1       120538  AAAGY             ALTANA AKTIENGESELLSCHAFT
# 4       SF1       155760   AAAP  ADVANCED ACCELERATOR APPLICATIONS SA
# ...     ...          ...    ...                                   ...
# 45747   SFP       111633   ^DJI          DOW JONES INDUSTRIAL AVERAGE
# 45748   SFP       111631  ^GSPC                               S&P 500
# 45749   SFP       111632  ^IXIC                      NASDAQ COMPOSITE
# 45750   SFP       111629   ^RUT                          RUSSELL 2000
# 45751   SFP       111630   ^VIX                 CBOE VOLATILITY INDEX
#
#       exchange isdelisted               category     cusips  siccode  \
# 0         NYSE          N  Domestic Common Stock  00846U101   3826.0
# 1         NYSE          N  Domestic Common Stock  013872106   3334.0
# 2       NASDAQ          Y  Domestic Common Stock  007231103   6022.0
# 3         NYSE          Y       ADR Common Stock  02143N103   2834.0
# 4       NASDAQ          Y       ADR Common Stock  00790T100   2834.0
# ...        ...        ...                    ...        ...      ...
# 45747    INDEX          N                    IDX       None      NaN
# 45748    INDEX          N                    IDX       None      NaN
# 45749    INDEX          N                    IDX       None      NaN
# 45750    INDEX          N                    IDX       None      NaN
# 45751    INDEX          N                    IDX       None      NaN
#
#                                sicsector  ...  firstadded  firstpricedate  \
# 0                          Manufacturing  ...  2014-09-26      1999-11-18
# 1                          Manufacturing  ...  2016-11-01      2016-11-01
# 2      Finance Insurance And Real Estate  ...  2017-09-09      1998-09-25
# 3                          Manufacturing  ...  2018-02-13      2002-05-22
# 4                          Manufacturing  ...  2016-05-19      2015-11-11
# ...                                  ...  ...         ...             ...
# 45747                               None  ...  2019-02-03      1986-01-01
# 45748                               None  ...  2019-02-03      1986-01-01
# 45749                               None  ...  2019-02-03      1986-01-01
# 45750                               None  ...  2019-02-03      1987-09-10
# 45751                               None  ...  2019-02-03      1990-01-02
#
#       lastpricedate firstquarter lastquarter  \
# 0        2024-10-17   1997-06-30  2024-06-30
# 1        2024-10-17   2014-12-31  2024-06-30
# 2        2003-01-28   1997-09-30  2002-09-30
# 3        2010-08-12   2000-12-31  2005-12-31
# 4        2018-02-09   2012-12-31  2017-09-30
# ...             ...          ...         ...
# 45747    2024-10-16         None        None
# 45748    2024-10-16         None        None
# 45749    2024-10-16         None        None
# 45750    2024-10-16         None        None
# 45751    2024-10-16         None        None
#
#                                               secfilings  \
# 0      https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 1      https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 2      https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 3      https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 4      https://www.sec.gov/cgi-bin/browse-edgar?actio...
# ...                                                  ...
# 45747                                               None
# 45748                                               None
# 45749                                               None
# 45750                                               None
# 45751                                               None
#
#                    companysite  active   foreign         class
# 0      https://www.agilent.com  Active  Domestic  Common Stock
# 1         http://www.alcoa.com  Active  Domestic  Common Stock
# 2                         None  Active  Domestic  Common Stock
# 3                         None  Active   Foreign  Common Stock
# 4                         None  Active   Foreign  Common Stock
# ...                        ...     ...       ...           ...
# 45747                     None  Active  Domestic          None
# 45748                     None  Active  Domestic          None
# 45749                     None  Active  Domestic          None
# 45750                     None  Active  Domestic          None
# 45751                     None  Active  Domestic          None
#
# [28782 rows x 31 columns]

# %%
import pandas as pd


import pandas as pd
import os
from datetime import datetime, timedelta

import os
import pandas as pd
from datetime import datetime, timedelta

def classify_etf_active(category):
    if category is None:
        return "Active"  # or any other default value you see fit
    return "Passive" if "ETF" in category else "Active"

def classify_foreign_domestic(category):
    if category is None:
        return "Domestic"  # or any other default value you see fit
    return "Foreign" if "ADR" in category or "Canadian" in category else "Domestic"

def classify_stock_type(category):
    if category is None:
        return None  # or any other default value you see fit
    if "Common Stock" in category:
        return "Common Stock"
    elif "CEF" in category:
        return "Closed-End Fund"
    elif "ETF" in category:
        return "Exchange-Traded Fund"
    elif "ETN" in category:
        return "Exchange-Traded Note"
    elif "UNIT" in category:
        return None

def rename_tickers(tickers_meta):
    rename_dict = {
        '3 - Small': 'small',
        '2 - Micro': 'micro',
        '4 - Mid': 'medium',
        '5 - Large': 'large',
        '1 - Nano': 'nano',
        '6 - Mega': 'mega'
    }
    tickers_meta['scalemarketcap'] = tickers_meta['scalemarketcap'].replace(rename_dict)
    return tickers_meta

def save_or_update_tickers(output_directory, output_filename, download_url, service_account_info):
    # Create the directory if it doesn't exist
    os.makedirs(output_directory, exist_ok=True)

    # Full path for the output file
    output_path = os.path.join(output_directory, output_filename)

    # Check if the file exists
    file_exists = os.path.exists(output_path)
    file_is_recent = False

    # If file exists, check if it's older than 7 days
    if file_exists:
        file_age = datetime.now() - datetime.fromtimestamp(os.path.getmtime(output_path))
        file_is_recent = file_age < timedelta(days=7)

    # If the file does not exist or is older than 7 days, download it
    if not file_exists or not file_is_recent:
        print("Downloading and saving new file.")
        tickers_meta = pd.read_parquet(download_url)
        
        # Classify tickers
        tickers_meta["active"] = tickers_meta["category"].apply(classify_etf_active)
        tickers_meta["foreign"] = tickers_meta["category"].apply(classify_foreign_domestic)
        tickers_meta["class"] = tickers_meta["category"].apply(classify_stock_type)
        
        # Remove rows where 'ticker' is None
        tickers_meta = tickers_meta.dropna(subset=['ticker']).drop_duplicates(["ticker"]).dropna(subset=["ticker"])

        # Rename tickers
        tickers_meta = rename_tickers(tickers_meta)

        print(tickers_meta[["scalemarketcap"]].head())
        
        tickers_meta.to_parquet(output_path)
        print(output_path)
    else:
        print(output_path)
        print("File is up-to-date, no need to download.")

# Example usage
# save_or_update_tickers('output_directory', 'output_filename.parquet', 'download_url', 'service_account_info')


# Example usage
output_directory = '../../sovai/assets/'
output_filename = 'tickers.parq'
download_url = "gs://sovai-accounting/dataframes/tickers.parq"

save_or_update_tickers(output_directory, output_filename, download_url, service_account_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 97
#      94 output_filename = 'tickers.parq'
#      95 download_url = "gs://sovai-accounting/dataframes/tickers.parq"
# ---> 97 save_or_update_tickers(output_directory, output_filename, download_url, service_account_info)
#
# NameError: name 'service_account_info' is not defined

# %%
import os 
output_directory = 'data'
output_filename = "features_mapping.parq"
output_path = os.path.join(output_directory, output_filename)

# %%
output_path
# Out:
# 'data/features_mapping.parq'

# %%
import pandas as pd
featies = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTjJfxQIOXMbW4iExhqjb3T8iygPKmfSNoAvrhu7v8L2txFUCoASZq9iW7ITbpnHaHk-5I3qHzrnX8M/pub?gid=0&single=true&output=csv")
featies.to_parquet(output_path)
