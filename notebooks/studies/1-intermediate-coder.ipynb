# %%
# !pip install uv && uv pip install sovai['full'] --system > output.log 2>&1

# %% [markdown]
# <a href="https://colab.research.google.com/gist/firmai/818a2e56c2e0f61c650e1080ce670ec1/1-intermediate-coder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Intermediate Coder
#
#
# ```python
# import pandas as pd
# ```
#
# Behold this line of code! It's a mystical incantation that opens the door to a secret society, a society that all quant-loving coders aspire to join!
#
# --------------
#
# So, what exactly is this Pandas?
#
# * First, imagine Pandas as a Swiss Army knife of data manipulation! It's a library, a powerful toolbox for coding, teeming with functions to make your life easier. And yes, there are many such toolboxes, each unique and magical in its own way. Check them out on [Github](https://github.com/trending/python?since=monthly) and [PyPi](https://pypi.org/search/?c=Topic+%3A%3A+Office%2FBusiness+%3A%3A+Financial+%3A%3A+Investment&o=-created&q=&page=1).
# * You can acquire your Pandas (don't worry, it's completely legal and cruelty-free) by simply running `!pip install pandas` in your terminal. Welcome to the club!
#
#
# And guess what? Libraries like Pandas are so incredibly handy, that they're already set up and ready to go on platforms like this Google Colab notebook. It's like having your toolkit already laid out for you. Let's see which version of our magic toolbox, Pandas, we have available. Don't be shy, peek in!

# %%
import pandas as pd

pd.__version__

# %% [markdown]
# You might see the following messsage "Warning this notebook was not authored by Google" just click ``Run
#
# 1.   List item
# 2.   List item
#
# Anyway`` ✅

# %% [markdown]
# * Well, it seems we're dealing with a vintage (old) version of Pandas here! We know that because of the above code ``pd.__version__``.
#
# * Let's dive into the depths of ``PyPi``, the mystical vault teeming with the latest and greatest software libraries, to grab the latest version.
#
# * Let's search for 'pandas pypi' in the grand oracle, Google. And voila! The very first treasure on the list, ``Pandas`` PyPi, is our golden ticket.  https://pypi.org/project/pandas/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Yes, we can confirm that we have an old version, just look at the [PyPi](https://pypi.org/project/pandas/) page its **2.03** instead of **1.53**:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To install the latest version of Pandas, we'll utilize the command ```!pip install command.```. The added **exclamation mark** isn't merely a mark of our excitement—it's a specific command that engages with the shell, or terminal.
#
# >   A shell is a user interface for access to an operating system’s services. Most often the user interacts with the shell using a command-line interface (CLI). The terminal is a program that opens a graphical window and lets you interact with the shell.
#
#
#
# And remember, we're after the most current version. So, our next step is to navigate to the **Release History** section on the Pandas PyPi page.
#
#
# ![Untitled scene(8).png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install pandas==2.2.2 ## okay nothing to be scared of, let's run this for the latest version

# %% [markdown]
# ***Sometimes!!*** we get a scary red message that tells us to restart the runtime, what does that mean?? Well it means we have to click <strong><font size=3 color="orange">Runtime</font></strong>   <strong><font size=3 color="orange">-> Restart runtime</font></strong>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Okay but why restart the library? Well the problem is the old library is already loaded in memory, and we have to purge it! We want the new library to be loaded in memory, and the easiest wat is to restart the runtime (kernel). This simply means that our Python environment needs a refresh.
# ![image.png](data:image/png;base64,...)

# %%
## You don't have to run pip install again, we have already done it once! (start here now and see if we have loaded the latest version)
## If it says anything other than 2.0.3 (like 1.5.3) then you forgot to restart the notebook.
import pandas as pd

pd.__version__

# %% [markdown]
# Okay, you now learned how to grab a specific version of a python library, which is a very useful skill to have. However, now I will show you there are actually a MUCH EASIER way to do it, if you just want the `latest` version.

# %%
# !pip install --upgrade pandas

# %%
# !pip install --upgrade polars

# %% [markdown]
# ## Pandas
# Okay, but so what is Pandas?
#
# Pandas is a Python library that provides tools for handling and analyzing data in a way that's easy to understand and use, similar to working with tables in a spreadsheet.

# %% [markdown]
# ![Untitled scene(17).png](data:image/png;base64,...)

# %% [markdown]
# From here onwards, I just want you to run the code, interact with the code, change the code, and get familiar with the pandas format.
#
# * Start by running the existing code, understanding its output, and predicting what will happen when you modify it. This hands-on experience, coupled with active problem-solving, will accelerate your learning.
#
# * Remember, you can't break anything! If your code doesn't run as expected, consider it an opportunity to learn and troubleshoot. Change parameters, experiment with different functions, and see what happens.
#
# * In the process, you'll become more familiar with how data is structured in Pandas and how to manipulate it. Keep practicing, keep experimenting, and have fun exploring the robust capabilities of the Pandas library!

# %%
import polars as pl
import pandas as pd
import numpy as np

# %%
df_pa = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}); df_pa

# %%
df_pl = pl.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}); df_pl

# %% [markdown]
# ##Creating a Series and accessing elements

# %% [markdown]
# To create some fake data, I will import a new library called numpy, infact it automatically gets installed when you install pandas, if you don't believe me search for `numpy>=` using Ctrl + F. Pandas is built ontop of numpy for that reason it has to be installed as well.

# %% [markdown]
# The above function `pd.DataFrame` is used for **multiple columns**, and `pd.Series` is used for a **single column**:

# %%
import numpy as np
# create a Series from a NumPy array of random values
np.random.seed(1)
s_pa = pd.Series(np.random.randn(100))
s_pa

# %%
import numpy as np

# create a Series from a NumPy array of random values
np.random.seed(1)# Create a Polars Series from a NumPy array of random values
s_pl = pl.Series(np.random.randn(100))

s_pl

# %% [markdown]
# Selection with square brackets `[number]`

# %%
# select item with matching label of 2
s_pa[2]

# %%
# select item with matching label of 2
s_pl[2]

# %%
# Select the elements from the Series 's' that are at the positions 2, 5, and 20.
s_pa[[2, 5, 20]]

# %%
# Select the elements from the Series 's' that are at the positions 2, 5, and 20.
s_pl[[2, 5, 20]]

# %%
# slice the Series
s_pa[3:8]

# %%
# slice the Series
s_pl[3:8]

# %%
s_pa.head() #top five

# %%
s_pl.head() #top ten

# %%
s_pa.tail() #bottom five

# %%
s_pl.tail() #bottom ten

# %%
s_pa.sort_values()

# %%
s_pa.index # type of index we have

# %% [markdown]
# Whattt???

# %%
s_pl.index # Polars has no index!

# %%
s_pa.values # turn pandas (dataframe) to numpy (array)

# %%
s_pl.to_numpy() # turn polars (dataframe) to numpy (array)

# %%
# specify an index at creation time
s2_pa = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
s2_pa

# %%
# Create a Polars DataFrame with the index as a separate column
s2_pl = pl.DataFrame({
    "index": ['a', 'b', 'c', 'd'],
    "values": [1, 2, 3, 4]
})

s2_pl

# %%
# In finance, we often use date indices for time series data, as it allows us to easily track data over time.

# Use the pandas date_range function to create a datetime index.
# The start date is '2023-01-01' and the period is 4, which means it will generate 4 dates starting from '2023-01-01'.
date_index = pd.date_range(start='2023-01-01', periods=4)

# Create a pandas Series with the datetime index.
# The Series 's2' will contain the values [1, 2, 3, 4] and each value will be associated with a date from the datetime index.
s2_pa = pd.Series([1, 2, 3, 4], index=date_index)

# Display the Series 's2'.
s2_pa

# %%
import polars as pl

# Define the start date
start = pl.lit("2023-01-01").str.strptime(pl.Date)

# Create the date range
date_range = pl.select(
    pl.date_range(start, start.dt.offset_by("3d"))
).to_series().to_list()

# Create the DataFrame
s2_pa = pl.DataFrame({
    "date": date_range,
    "value": [1, 2, 3, 4]
})

s2_pa

# %%
# In colab you can either just have the output you want to view at the BOTTOM of the cell
s2_pa

# %%
# Or you can have a print statement and have it anywhere in the block
print(s2_pa)

# %% [markdown]
# ##Size, shape, uniqueness and counts of values

# %%
# Create a pandas Series 's' with the given list of values.
# The list contains the numbers and one NaN (Not a Number) value.
# NaN is a special floating-point value that represents missing or undefined data.

s_pa = pd.Series([5, 0, 1, 1, 2, 3, 4, 5, 6, np.nan])

# Use the len() function to get the length of the Series 's', which is the total number of elements in the series.
len(s_pa)

# %%
s_pa

# %%
# Use the .shape attribute to get the shape of the Series 's'.
# The shape is a tuple that gives the dimensions of the Series.
# For a Series, the shape will be a single-value tuple that contains the total number of elements (length) in the Series.

s_pa.shape

# %%
# .count() is the number of non NaN values
s_pa.count()

# %%
# all unique values
s_pa.unique()

# %%
# all unique values and their counts (basically just counting values)
s_pa.value_counts()

# %%
import polars as pl
import numpy as np

# Create a Polars Series 's_pl' with the given list of values
s_pl = pl.Series([5, 0, 1, 1, 2, 3, 4, 5, 6, None])  # Note: We use None instead of np.nan in Polars

# Get the length of the Series
len_s_pl = len(s_pl)
print("Length:", len_s_pl)

# Get the shape of the Series
shape_s_pl = s_pl.shape
print("Shape:", shape_s_pl)

# Count non-null values
count_s_pl = s_pl.count()
print("Count of non-null values:", count_s_pl)

# Get unique values
unique_s_pl = s_pl.unique()
print("Unique values:", unique_s_pl)

# Get value counts
value_counts_s_pl = s_pl.value_counts()
print("Value counts:")
value_counts_s_pl

# %%
# Create a pandas Series 'tickers' with a list of ticker symbols.
# The list contains the symbols 'AAPL', 'MSFT', 'GOOG', 'AAPL', 'AAPL', 'MSFT', 'TSLA', 'TSLA', 'GOOG', 'AAPL'.
# Note that some ticker symbols appear more than once in the list.

tickers = pd.Series(['AAPL', 'MSFT', 'GOOG', 'AAPL', 'AAPL', 'MSFT', 'TSLA', 'TSLA', 'GOOG', 'AAPL'])

# Use the .value_counts() method to count the occurrences of each unique value in the 'tickers' Series.
# This will return a new Series where the index is the unique ticker symbols and the values are the counts of each ticker.
# This is useful for understanding the distribution of values in the 'tickers' Series.

ticker_counts = tickers.value_counts()

# Display the 'ticker_counts' Series.
ticker_counts

# %%
import polars as pl

# Create a Polars Series 'tickers' with a list of ticker symbols
tickers_pl = pl.Series(['AAPL', 'MSFT', 'GOOG', 'AAPL', 'AAPL', 'MSFT', 'TSLA', 'TSLA', 'GOOG', 'AAPL'])

# Use the value_counts() method to count the occurrences of each unique value in the 'tickers' Series
ticker_counts_pl = tickers_pl.value_counts()

# Display the 'ticker_counts' DataFrame
ticker_counts_pl

# %% [markdown]
# ##Alignment via index labels

# %%
s3 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
s3

# %%
s4 = pd.Series([4, 3, 2, 1], index=['d', 'c', 'b', 'a'])
s4

# %%
# add s3 and s4 values together
s3 + s4

# %%
## Because Polars have no index, addition is harder
import polars as pl

# Create Polars DataFrames instead of Series
df3 = pl.DataFrame({
    "index": ['a', 'b', 'c', 'd'],
    "value": [1, 2, 3, 4]
})

df4 = pl.DataFrame({
    "index": ['d', 'c', 'b', 'a'],
    "value": [4, 3, 2, 1]
})

# Perform the addition
result = (
    df3.join(df4, on="index", how="outer", suffix="_df4")
    .with_columns([
        pl.col("value").fill_null(0),
        pl.col("value_df4").fill_null(0),
        (pl.col("value") + pl.col("value_df4")).alias("sum")
    ])
    .select(["index", "sum"])
    .sort("index")
)

print(result)

# %%
result

# %%
# see how it is different from adding numpy arrays (not index alligned)

a1 = np.array([1, 2, 3, 4])
a2 = np.array([4, 3, 2, 1])
a1 + a2

# %% [markdown]
# #Creating a DataFrame

# %%
# create a DataFrame from a 2-d ndarray
df_pa = pd.DataFrame(np.array([[10, 11], [20, 21]]), columns=['A', 'B'])

df_pa

# %%
# Create a DataFrame from a 2-d NumPy array
df_pl = pl.DataFrame(np.array([[10, 11], [20, 21]]), schema=['A', 'B'])

df_pl

# %%
# what's the shape of this DataFrame
df_pa.shape  # it is two rows by 5 columns

# %%
df_pl.shape

# %%
# what are names of the columns?
df_pa.columns

# %%
df_pa.columns = ['c1', 'c2']
df_pa

# %%
df_pl.columns

# %%
df_pl.columns = ['c1', 'c2']
df_pl

# %% [markdown]
# ##Example data

# %%
# Use the pandas read_csv function to read in data from a CSV file located at the given URL.
# The 'index_col' parameter is set to 'Symbol', which means that the 'Symbol' column in the CSV file will be used as the index in the resulting DataFrame.
# The 'usecols' parameter is set to [0, 2, 3, 7], which means that only the columns in positions 0, 2, 3, and 7 in the CSV file will be read into the DataFrame.
# This can be useful for reducing memory usage when working with large CSV files, as it allows you to only load the specific columns that you need.

sp500 = pd.read_csv("https://storage.googleapis.com/public-quant/random/sp500.csv",
                    index_col='Symbol',
                    usecols=[0, 2, 3, 7])

# %%
# peek at the first 5 rows of the data using .head()
sp500.head()

# %%
import polars as pl

# Use the Polars read_csv function to read in data from a CSV file located at the given URL.
sp500_pl = pl.read_csv("https://storage.googleapis.com/public-quant/random/sp500.csv",
                       columns=['Symbol', 'Sector', 'Price', 'Book Value'])

sp500_pl.head(5)

# %%
# examine the index
sp500.index

# %% [markdown]
# ###Selecting columns of a DataFrame

# %%
sp500

# %% [markdown]
# In Pandas you can subset a dataframe with .loc[], .iloc[] or just [].

# %%
# get first and second rows (1 and 2) by location
sp500.iloc[[0, 2]]

# %%
sp500_pl[[1, 2]]

# %%
# get first and second rows and the first and second column [[rows],[columns]]
sp500.iloc[[1, 2],[1, 2]]

# %%
sp500_pl[[1, 2]].select([pl.col(sp500_pl.columns[i]) for i in [0, 2, 3]])

# %%
# get price column by name
# result is a Series
sp500['Price'].head()

# %%
sp500_pl['Price'].head()

# %%
# get Price and Sector columns
# since a list is passed, result is a DataFrame
sp500[['Price', 'Sector']]

# %%
# get Price and Sector columns
# since a list is passed, result is a DataFrame
sp500_pl[['Price', 'Sector']]

# %% [markdown]
# ##Selecting rows of a DataFrame

# %% [markdown]
# ###Slicing using the [] operator

# %%
# first three rows
sp500[:3]

# %%
sp500_pl.slice(0, 3)

# %%
# XYL through YUM labels
sp500['XYL':'YUM']

# %%
sp500_pl.filter(
    (pl.col('Symbol') >= 'XYL') & (pl.col('Symbol') <= 'YUM')
)

# %% [markdown]
# ###Selecting rows by index label and location: `.loc[]` and `.iloc[]`
#
# `loc` means text and `iloc` means integer location, so let's filter by text location.

# %%
# get row with label MMM
# returned as a Series
sp500.loc['MMM']

# %%
# rows with label MMM and MSFT
# this is a DataFrame result
sp500.loc[['MMM', 'MSFT']]

# %%
## we use filter where we don't want location
sp500_pl.filter(pl.col('Symbol').is_in(['MMM', 'MSFT']))

# %%
# get rows in location 0 and 2
sp500.iloc[[0, 2]]

# %%
# get rows in location 0 and 2
sp500_pl[[0, 2]]

# %%
# Use the .get_loc() method of the DataFrame's index to find the location of 'MMM' and 'A' in the index.
# The .get_loc() method returns an integer that represents the position of the label in the index.
# This can be useful when you need to know the exact position of certain labels in the index for further operations.

i1 = sp500.index.get_loc('MMM')
i2 = sp500.index.get_loc('A')

# Print the locations of 'MMM' and 'A' in the index.
i1, i2

# %%
# and get the rows
sp500.iloc[[i1, i2]]

# %%
import polars as pl

def get_loc(df, column, value):
    return df.with_row_index('row_number').filter(pl.col(column) == value).select('row_number').item()

# Assuming sp500_pl is your Polars DataFrame and 'Symbol' is the column containing the symbols

# Find the positions of 'MMM' and 'A'
i1 = get_loc(sp500_pl, 'Symbol', 'MMM')
i2 = get_loc(sp500_pl, 'Symbol', 'A')

# Print the locations of 'MMM' and 'A'
i1, i2

# %%
# and get the rows
sp500_pl[[i1, i2]]

# %% [markdown]
# ### Cell lookup by label or location using .at[] and .iat[]

# %%
# by label in both the index and column
sp500.at['MMM', 'Price']

# %%
sp500_pl.filter(pl.col('Symbol') == 'MMM').select('Price').item()

# %% [markdown]
# ##Selecting rows using Boolean selection

# %%
# what rows have a price < 100?
sp500.Price < 100

# %%
sp500_pl['Price'] < 100

# %%
# now get the rows with Price < 100
sp500[sp500.Price < 100]

# %%
sp500_pl.filter(pl.col('Price') < 100)

# %%
# get only the Price where Price is < 10 and > 0
sp500[(sp500.Price < 10) & (sp500.Price > 0)] [['Price']]

# %%
sp500_pl.filter((pl.col('Price') < 10) & (pl.col('Price') > 0)).select(['Symbol','Price'])

# %% [markdown]
# ##Arithmetic on a DataFrame

# %%
# set the random seed to allow for replicatable results
np.random.seed(123456)

# create the DataFrame
df = pd.DataFrame(np.random.randn(5, 4),
                  columns=['A', 'B', 'C', 'D'])
df

# %%
# multiply everything by 2
df * 2

# %%
# deduct the first row from every row
df - df.iloc[0]

# %%
# get rows 1 through 3, and only B, C columns
subframe = df[1:4][['B', 'C']]

# we have extracted a little square in the middle of df
subframe

# %%
# demonstrate the alignment of the subtraction
df - subframe

# %%
# get the A column
a_col = df['A']
df.sub(a_col, axis=0)

# %% [markdown]
# #Reindexing Series and DataFrame objects

# %%
# create a series of five random numbers
np.random.seed(1)
s = pd.Series(np.random.randn(5))
s

# %%
# now set the index to alpha values
s.index = ['a', 'b', 'c', 'd', 'e']
s

# %%
# reindex the copy
s2 = s.reindex(['a', 'c', 'e', 'g'])
# change the value at 'a'
s2['a'] = 0
s2

# %%
s['a']

# %%
# Series objects with string and integer index types
# with the "same" values will not align

s1 = pd.Series([0, 1, 2], index=[0, 1, 2])
s2 = pd.Series([3, 4, 5], index=['0', '1', '2'])
s1 + s2

# %%
# demonstrate treating values at a specific type
s2.index = s2.index.values.astype(int)
s1 + s2

# %%
# show reindexing with filling of NaN with a specified value
s2 = s.copy()
s2.reindex(['a', 'f'], fill_value=0)

# %%
# a Series to demonstrate reindexing
s3 = pd.Series(['red', 'green', 'blue'], index=[0, 3, 5])
s3

# %%
# forward fill (last known value technique)
s3.reindex(np.arange(0,7), method='ffill')

# %%
# demonstrate how backwards fill differs
s3.reindex(np.arange(0,7), method='bfill')

# %% [markdown]
# #Reshaping, Reorganizing and Aggregation

# %%
# import pandas and NumPy
import pandas as pd
import numpy as np

# date and time functions
import datetime

# bring in matplotlib and draw inline
import matplotlib.pyplot as plt
# %matplotlib inline

# Set some Pandas options for table display i.e., how many columns, how many rows (you don't have to specify these)
pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 8)

# %% [markdown]
# ##Loading historical stock data from the web or from files

# %% [markdown]
# ###From file

# %%
import pandas as pd

# Read the Microsoft and Apple data from file (parse_dates says you have a date index)
msft = pd.read_csv("https://storage.googleapis.com/public-quant/random/MSFT.csv", index_col=0, parse_dates=True)
aapl = pd.read_csv("https://storage.googleapis.com/public-quant/random/AAPL%202.csv", index_col=0, parse_dates=True)

# Select dates between 2016 and 2020
msft = msft.loc['2016-01-01':'2020-12-31']
aapl = aapl.loc['2016-01-01':'2020-12-31']

# %% [markdown]
# ###Organizing the data for the examples

# %%
msft[:3]

# %%
aapl[:3]

# %% [markdown]
# #Reorganizing and reshaping data

# %% [markdown]
# ##Concatenating data in Multiple DataFrame objects

# %%
msft

# %%
# get MSFT adjusted close data for Jan and Feb 2012
msftA01 = msft['2017-01-01':'2019-01-31'][['Adj Close']]
msftA02 = msft['2017-02-01':'2019-02-28'][['Adj Close']]
msftA01[:3]

# %%
msftA02[:3]

# %%
# combine the first three rows of each of msftA01 and msftA02
pd.concat([msftA01.head(3), msftA02.head(3)])

# %%
# Extract only the Jan 2012 AAPL values.
aaplA01 = aapl['2017-01-01':'2019-01-31'][['Adj Close']]
# now concat the AAPL and MSFT Jan 2012 data
# there will be duplicate index labels
withDups = pd.concat([msftA01[:3], aaplA01[:3]])
withDups

# %%
# show the two records for data of 2012-01-03
withDups.loc['2017-01-03']

# %%
# demonstrate concat with a specification of the
# stock tickets being part of the index
# this help disambiguate the duplicate dates using
# a hierarchal index (muli-index) which is important in finance
closes = pd.concat([msftA01[:3], aaplA01[:3]],
                    keys=['MSFT', 'AAPL'])
closes

# %%
# extract just MSFT values using .ix
closes.loc['MSFT'][:3]

# %%
# demonstrate concatenation using two DataFrame's
# that each have two columns.  pandas will align the
# data in columns by the column names (labels)
msftAV = msft[['Adj Close', 'Volume']]
aaplAV = aapl[['Adj Close', 'Volume']]
pd.concat([msftAV, aaplAV])

# %%
# demonstrate concatenation with DataFrame objects
# that do not have the same set of columns leading to NaN values

aaplA = aapl[['Adj Close']]
pd.concat([msftAV, aaplA])

# %%
# perform an inner join on the DataFrame's
# since aaplA does not have a Volume column, pandas
# will not include that column in the result

pd.concat([msftAV, aaplA], join='inner')

# %%
# concat along the rows, causing duplicate columns to
# be created in the result

msftA = msft[['Adj Close']]
closes = pd.concat([msftA, aaplA], axis=1)
closes[:3]

# %%
# concat along rows using two DataFrame objects with
# different number of rows. This demonstrates how
# NaN values will be filled in those rows for AAPL
# which only has three rows compared to 5 for MSFT

pd.concat([msftAV[:5], aaplAV[:3]], axis=1,
          keys=['MSFT', 'AAPL'])

# %%
# inner join can also be used along this axis
# this will not include rows with index labels that do...
# not exist in both DataFrame objects

pd.concat([msftA[:5], aaplA[:3]], axis=1,
          join='inner', keys=['MSFT', 'AAPL'])

# %%
# ignore indexes and just concatenate the data and
# have the resultbe a default integer index

pd.concat([msftA[:3], aaplA[:3]], ignore_index=True)

# %% [markdown]
# ##Merging DataFrame objects

# %%
# we will merge these two DataFrame objects,
# so lets peek at the data to remind ourselves
# what they contain
msftAR = msftA.reset_index()
msftVR = msft[['Volume']].reset_index()

msftVR[:3]

# %%
msftAR[:3]

# %%
# merge the two, pandas automatically finds the columns in common,
# in this case Date, and merges on that column and adds
# a column for all the other columns in both DataFrame's

msftCVR = pd.merge(msftAR, msftVR)
msftCVR[:5]

# %%
# we will demonstrate join semantics using this DataFrame

msftAR0_5 = msftAR[0:5]
msftAR0_5

# %%
# and also this one

msftVR2_4 = msftVR[2:4]
msftVR2_4

# %%
# merge semantics using default inner join

pd.merge(msftAR0_5, msftVR2_4)

# %%
# same join but using outer

pd.merge(msftAR0_5, msftVR2_4, how='outer')

# %% [markdown]
# ##Pivoting

# %%
msft.index

# %%
aapl.index

# %%
# need to insert Symbol column before combining
msft.insert(0, 'Symbol', 'MSFT')
aapl.insert(0, 'Symbol', 'AAPL')

# %%
# concatenate the MSFT and AAPL data
# index will consist of the Date column, which we will sort
combined = pd.concat([msft.tail(1000), aapl.tail(1000)]).sort_index()

# this pushes the index into a column and resets to a
# default integer index
s4p = combined.reset_index();
s4p[:5]

# %%
s4p

# %%
# Use the .pivot() method of the DataFrame 's4p' to reshape the data.
# The 'index' parameter is set to 'Date', which means that the unique values in the 'Date' column will become the index in the resulting DataFrame.
# The 'columns' parameter is set to 'Symbol', which means that the unique values in the 'Symbol' column will become the column labels in the resulting DataFrame.
# The 'values' parameter is set to 'Adj Close', which means that the values in the 'Adj Close' column will become the data in the resulting DataFrame.
# This reshaping of the data can be useful when you want to analyze the 'Adj Close' values for each 'Symbol' over time.

closes = s4p.pivot(index='Date', columns='Symbol',
                   values='Adj Close')

# Print the first three rows of the reshaped DataFrame.
closes[:3]

# %% [markdown]
# **Pandas** can quickly create Pivot Tables, in **Excel** you would have to do the following:
#
#     1. Open your Excel workbook that contains your s4p data.
#
#     2. Select any cell within your data range.
#
#     3. Go to Insert > PivotTable.
#
#     A dialog box will pop up, prompting you to choose the data that you want to analyze and where you want to place the PivotTable. The data range should already be filled in if you clicked on a cell within your data. Choose a location (a new worksheet is common).
#
#     4. Click OK.
#
#     5. Once you've initialized the PivotTable, Excel will open the "PivotTable Fields" pane on the right-hand side.
#
#     6. Based on the instruction:
#         Drag "Date" to the Rows section.
#         Drag "Symbol" to the Columns section.
#         Drag "Adj Close" to the Values section.
#
#     The PivotTable will now be reshaped according to your instructions, showing the 'Adj Close' values for each 'Symbol' over the dates.

# %% [markdown]
# ##Stacking and Unstacking

# %%
closes

# %%
# Use the .stack() method of the DataFrame 'closes' to "stack" the first level of columns into the index.
# This will move the 'AAPL' and 'MSFT' column labels into the index, resulting in a Series with a MultiIndex.
# The MultiIndex will contain the 'Date' and 'Symbol' values, and the data in the Series will be the 'Adj Close' values.
# This reshaping of the data can be useful when you want to analyze the 'Adj Close' values for each 'Symbol' over time in a different format.

stackedCloses = closes.stack()

# Print the 'stackedCloses' Series.
stackedCloses

# %% [markdown]
# That simple `stack()` command is all you need, in Excel the following steps would be necessary:
#
# Excel doesn't have a direct one-click feature to mimic the exact behavior of the `.stack()` method, but you can recreate this effect manually using a combination of copy-pasting and Excel's features. Here's how:
#
#     Duplicate Data:
#         Start by duplicating your closes table to a new worksheet or a clear section of your current worksheet. This allows you to manipulate the data without affecting the original PivotTable.
#
#     Unpivot Data Using Power Query:
#         Highlight your table.
#         Go to the Ribbon > Data > Get & Transform Data > From Table/Range.
#         This will open up the Power Query window.
#         Select the 'Date' column, then go to the Transform tab > Unpivot Columns > Unpivot Other Columns.
#         This will transform the data into a format similar to what the `.stack()` method would achieve.
#         Rename columns if necessary (the column previously containing 'Symbol' names will probably be named 'Attribute' by default, and 'Value' will contain your 'Adj Close' data).
#         Click on Close & Load to load this table back into Excel.
#
#     Formatting:
#         Once back in Excel, your table should have three columns: 'Date', 'Symbol' (or whatever it's named after the unpivoting), and 'Adj Close'.
#         This table essentially represents your closes DataFrame post `.stack()` operation.

# %%
stackedCloses

# %%
# using .loc we can retrieve close values by
# specifying both the date and ticker
stackedCloses.loc['2018-01-03', 'AAPL']

# %%
# lookup on just the date, which will give us two values
# one each for AAPL and MSFT.
stackedCloses.loc['2012-01-03']

# %%
# this looks up all values for the MSFT symbol
stackedCloses.loc[:, 'MSFT']

# %%
# pivots the last level of the index back into a column
unstackedCloses = stackedCloses.unstack()
unstackedCloses[:3]

# %% [markdown]
# ##Melting

# %%
# Use the pandas melt function to reshape the DataFrame 's4p' into a format where each row represents a single observation over time.
# The 'id_vars' parameter is set to ['Date', 'Symbol'], which means that the 'Date' and 'Symbol' columns will be used as identifier variables.
# The remaining columns (not specified in 'id_vars') will be "melted" into two columns: one for the variable name (column name in the original DataFrame) and one for the value of that variable.
# This reshaping of the data can be useful when you want to analyze the data in a "long" format where each row represents a single observation.

melted = pd.melt(s4p, id_vars=['Date', 'Symbol'])

# Print the first five rows of the 'melted' DataFrame.
melted[:5]

# %% [markdown]
# **What about Excel?**
#
# The `pd.melt()` function from pandas reshapes data from a wide format to a long format. In Excel, the process to achieve this is called "unpivoting" and can be done using Power Query, similar to the previous explanation. Here's how you can simulate the melt operation in Excel:
#
#     Prepare Data:
#         Start by placing your s4p data into Excel, preferably in a table format. This can be done by selecting the data range and then using Insert > Table.
#
#     Unpivot Data Using Power Query:
#         Click on any cell within your table.
#         Go to the Ribbon > Data > Get & Transform Data > From Table/Range.
#         This will open up the Power Query window.
#         Hold the CTRL key and select both the 'Date' and 'Symbol' columns, as these are your identifier variables (similar to id_vars in pd.melt()).
#         Right-click on one of the highlighted columns and choose Unpivot Other Columns.
#         This action will transform the data into a long format.
#         Rename the newly created columns if necessary. By default, they will be named 'Attribute' (similar to the variable name or column name in the original data) and 'Value' (similar to the value of that variable).
#         Click on Close & Load to send this data back into Excel.
#
#     Inspect the Data:
#         Once back in Excel, your data will be in a long format with 'Date', 'Symbol', 'Attribute', and 'Value' columns.
#         To view the first five rows, simply scroll to the top of this new table.
#
# With these steps, you've essentially reshaped your data in Excel in a manner similar to using the `pd.melt()` function in pandas.

# %%
# extract the values for the data for MSFT on 2012-01-03

melted[(melted.Date=='2017-01-03') & (melted.Symbol=='MSFT')]

# %% [markdown]
# #Grouping and aggregation

# %% [markdown]
# ##Splitting

# %%
# Create a new DataFrame 's4g' from the 'combined' DataFrame, selecting only the 'Symbol' and 'Adj Close' columns.
# Use the .reset_index() method to reset the index of the DataFrame. This will move the index labels into a new column and create a default integer index.
s4g = combined[['Symbol', 'Adj Close']].reset_index()

# Use the pd.DatetimeIndex() function to convert the 'Date' column to a DatetimeIndex, and then extract the year and month as integers.
# Use the .insert() method to add these year and month values as new columns in the 's4g' DataFrame.
# The first parameter of .insert() is the location where the new column should be inserted (1 for 'Year', 2 for 'Month').
# The second parameter is the column label ('Year' or 'Month').
# The third parameter is the values to be inserted (the year or month values extracted from the 'Date' column).
s4g.insert(1, 'Year', pd.DatetimeIndex(s4g['Date']).year)
s4g.insert(2, 'Month',pd.DatetimeIndex(s4g['Date']).month)

# Print the first five rows of the 's4g' DataFrame.
s4g[:5]

# %%
# group by the Symbol column
s4g.groupby('Symbol')

# %%
# group again, but save the result this time
grouped = s4g.groupby('Symbol')

# the groupby object has a property groups, which shows how
# all rows will in mapped into the groups.
# the type of this object is a python dict
type(grouped.groups)

# %%
# show the mappings of rows to groups
grouped.groups

# %%
# these report the number of groups that resulted from the grouping
len(grouped), grouped.ngroups

# %%
# this function will print the contents of a group
def print_groups (groupobject):
    for name, group in groupobject:
        print(name)
        print(group.head())

# %%
# examine our resulting groups
print_groups(grouped)

# %%
# .size will tell us the count of items in each group
grouped.size()

# %%
# a specific group can be retrieved using .get_group()
# which returns a DataFrame representing the specified group
grouped.get_group('MSFT')

# %%
# group by three different fields and print the result
mcg = s4g.groupby(['Symbol', 'Year', 'Month'])
print_groups(mcg)

# %%
# set the index of the data to be the following three fields
# we are creating a multiindex

mi = s4g.set_index(['Symbol', 'Year', 'Month'])
mi

# %%
# now we can group based upon values in the actual index
# the following groups by level 0 of the index (Company)

mig_l1 = mi.groupby(level=0)
print_groups(mig_l1)

# %%
# group by three levels in the index using their names

mig_l12 = mi.groupby(level=['Symbol', 'Year', 'Month'])
print_groups(mig_l12)

# %% [markdown]
# #Aggregation

# %%
# Use the .agg() method of the grouped DataFrame 'mig_l12' to apply the numpy mean function to each group.
# The .agg() method applies the specified function to each group of values in the DataFrame.
# In this case, the numpy mean function will calculate the average of the values in each group.
# This can be useful when you want to summarize the data in each group with a single statistic.

mig_l12.agg(np.mean)

# %%
# example of groupby that also ignores the index
# resulting in a default integer index
# this also has the mean function applied

s4g.groupby(['Symbol', 'Year', 'Month'],
            as_index=False).agg(np.mean)[:5]

# %%
# apply multiple functions to each group in one call
mig_l12.agg([np.mean, np.std])

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 7)

# useful for date/time manipulations
import datetime
from datetime import datetime

# And some items for matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #Time-series data and the DatetimeIndex

# %%
# create a a DatetimeIndex from an array of datetime's
dates = [datetime(2018, 8, 1), datetime(2018, 8, 2)]
dti = pd.DatetimeIndex(dates)
dti

# %%
# a Series given a datetime list will automatically create
# a DatetimeIndex as its index

np.random.seed(123456)
ts = pd.Series(np.random.randn(2), dates)
type(ts.index)

# %%
# retrieve a value using a datetime object
ts[datetime(2018, 8, 2)]

# %%
# this can also be performed with a string
ts['2018-8-2']

# %%
# create a Series with a DatetimeIndex using strings as dates
np.random.seed(123456)
dates = ['2018-08-01', '2018-08-02']
ts = pd.Series(np.random.randn(2), dates)
ts

# %%
# convert a list of items to a DatetimeIndex (cool right?)
dti = pd.to_datetime(['Aug 1, 2018', '2018-08-02',
                      '2014.8.3', None],format='mixed')
dti

# %%
# watch out for this failure, it is clearly not a date
dti2 = pd.to_datetime(['Aug 1, 2018', 'willfailhere'])
type(dti2)

# %%
# coerce pandas to convert all to datetime and a DatetimeIndex
# substituting NaT where values can not be converted

pd.to_datetime(['Aug 1, 2018', 'foo'], errors='coerce')

# %%
# Use the pandas to_datetime function to convert a list of date strings to a DatetimeIndex.
# The first date string '8/1/2014' is in the format month/day/year, so it will be interpreted as August 1, 2014.
dti1 = pd.to_datetime(['8/1/2018'])

# The second date string '1/8/2014' is in the format day/month/year, but pandas defaults to interpreting dates in the format month/day/year.
# To correctly interpret this date as January 8, 2014, we need to set the 'dayfirst' parameter to True.
dti2 = pd.to_datetime(['1/8/2018'], dayfirst=True)

# Print the first (and only) date in each DatetimeIndex.
# Both dates should represent the same point in time: August 1, 2014.
dti1[0], dti2[0]

# %%
# create a Series with a DatetimeIndex starting at 8/1/2014
# consisting of 10 consecutive days

np.random.seed(123456)
dates = pd.date_range('8/1/2018', periods=10)
s1 = pd.Series(np.random.randn(10), dates)
s1[:5]

# %% [markdown]
# #Creating time-series with specific frequencies

# %%
# create a time-series with one minute frequency
bymin = pd.Series(np.arange(0, 90*60*24),
                  pd.date_range('2018-08-01',
                                '2018-10-29 23:59:00',
                                freq='T'))
bymin

# %%
# slice at the minute level
bymin['2018-08-01 12:30':'2018-08-01 12:59']

# %% [markdown]
# #Representing intervals of time using periods

# %%
# create a period representing a start of
# 2014-08 and for a duration of one month
aug2018= pd.Period('2018-08', freq='M')
aug2018

# %%
# pandas determined the following start and end
# for the period
aug2018.start_time, aug2018.end_time

# %%
# what is the one month period following the given period?
sep2018 = aug2018 + 1
sep2018

# %%
# the calculated start and end are
sep2018.start_time, sep2018.end_time

# %%
# create a pandas PeriodIndex
mp2017 = pd.period_range('1/1/2017', '12/31/2017', freq='M')
mp2017

# %%
# dump all the calculated periods
for p in mp2017:
    print("{0} {1} {2} {3}".format(p,
                                   p.freq,
                                   p.start_time,
                                   p.end_time))

# %%
# and now create a Series using the PeriodIndex

np.random.seed(123456)
ps = pd.Series(np.random.randn(12), mp2017)
ps

# %% [markdown]
# #Shifting and lagging time-series data

# %%
# for examples of data retrieval / slicing, we will use the
# following data from Yahoo! Finance
msft =  pd.read_csv("https://storage.googleapis.com/public-quant/random/MSFT.csv", index_col=0, parse_dates=True)

# extract just the Adj Close values
msftAC = msft['Adj Close']
msftAC.head(3)

# slicing using a DatetimeIndex nicely works with dates
# passed as strings
msft['2017-01-01':'2017-01-05']

# returns a Series representing all the values of the
# single row indexed by the column names
msft.loc['2017-01-03']

# this is a Series, so the lookup works
msftAC['2017-01-03']

# %%
# refresh our memory on the data in the MSFT closing prices Series
msftAC[:5]

# %%
# shift the prices one index position forward
shifted_forward = msftAC.shift(1)
shifted_forward[:5]

# %%
# the last item is also shifted away
msftAC.tail(5), shifted_forward.tail(5)

# %%
# shift backwards 2 index labels
shifted_backwards = msftAC.shift(-2)
shifted_backwards[:5]

# %%
# this has resulted in 2 NaN values at
# the end of the resulting Series
shifted_backwards.tail(5)

# %%
# shift by a different frequency does not realign
# and ends up essentially changing the index labels by
# the specific amount of time

msftAC.shift(1, freq="S")

# %%
# calculate the percentage change in closing price

msftAC / msftAC.shift(1) - 1

# %% [markdown]
# #Frequency conversion of time-series data

# %%
# take a two item sample of the msftAC data for demonstrations
sample = msftAC[:2]
sample

# %%
# demonstrate resampling to hour intervals
# realignment causes many NaN's

sample.asfreq("H")

# %%
# fill NaN's with the last know non-NaN valuen
sample.asfreq("H", method="ffill")

# %%
# fill with the "next known" value
sample.asfreq("H", method="bfill")

# %% [markdown]
# ##Up and down resampling of time-series

# %%
# calculate the cumulative daily returns for MSFT
msft_cum_ret = (1 + (msftAC / msftAC.shift() - 1)).cumprod()
msft_cum_ret

# %%
# resample to a monthly cumulative return
msft_monthly_cum_ret = msft_cum_ret.resample("M")
msft_monthly_cum_ret

# %%
# verify the monthly average for 2012-01
msft_cum_ret['2017-01'].mean()

# %%
# verify that the default resample techique is mean
msft_cum_ret.resample("M").mean()

# %%
# resample to monthly and give us open, high, low, close
msft_cum_ret.resample("M").ohlc()[:5]

# %%
# this will return an index with periods instead of timestamps
by_periods = msft_cum_ret.resample("M",kind="period").mean()
for i in by_periods.index[:5]:
    print("{0}:{1} {2}".format(i.start_time,
                                i.end_time,
                                by_periods[i]))

# %%
# upsampling will be demonstrated using the second
# and third values (first is NaN)
sample = msft_cum_ret[1:3]
sample

# %%
# upsampling this will have a lot of NaN's
by_hour = sample.resample("H")
by_hour

# %%
by_hour.interpolate()
