# %%
# !pip install sovai[full]

# %%
# !pip install edgartools==2.27.5

# %%
import sovai as sov

sov.token_auth(token="visit https://sov.ai/profile for your token")

# %%
sov.sec_search("CFO Resignation")
# Out:
# VBox(children=(HTML(value="<h2 style='color: #ffd700;'>EDGAR Search Tool</h2>"), HBox(children=(VBox(children=…

# %%
import pandas as pd
df = pd.read_csv("edgar_search_results/edgar_search_results_30092024_042718.csv")

# %%
df.head()
# Out:
#    root_form  form_name    filed_at reporting_for  \
# 0        NaN        NaN  2024-01-02    2023-12-29
# 1        NaN        NaN  2024-01-19    2024-01-19
# 2        NaN        NaN  2024-01-05    2024-01-02
# 3        NaN        NaN  2024-08-21    2024-08-21
# 4        NaN        NaN  2024-05-03    2024-05-01
#
#                                entity_name ticker company_cik  \
# 0                              AKUMIN INC.    NaN  0001776197
# 1               Freight Technologies, Inc.   FRGT  0001687542
# 2     PACIFIC HEALTH CARE ORGANIZATION INC   PFHO  0001138476
# 3                                  NFT Ltd     MI  0001958713
# 4  Paranovus Entertainment Technology Ltd.   PAVS  0001751876
#
#   company_cik_trimmed          place_of_business incorporated_location  \
# 0             1776197        Plantation, Florida       Ontario, Canada
# 1             1687542       The Woodlands, Texas                    []
# 2             1138476  Newport Beach, California                  Utah
# 3             1958713       Hong Kong, Hong Kong        Cayman Islands
# 4             1751876             Nanping, China        Cayman Islands
#
#      file_num   film_num                                file_num_search_url  \
# 0   001-39479   24502002  https://www.sec.gov/cgi-bin/browse-edgar/?file...
# 1   001-38172   24546386  https://www.sec.gov/cgi-bin/browse-edgar/?file...
# 2   000-50009   24517571  https://www.sec.gov/cgi-bin/browse-edgar/?file...
# 3  333-268865  241229330  https://www.sec.gov/cgi-bin/browse-edgar/?file...
# 4   001-39098   24913267  https://www.sec.gov/cgi-bin/browse-edgar/?file...
#
#                                   filing_details_url  \
# 0  https://www.sec.gov/Archives/edgar/data/177619...
# 1  https://www.sec.gov/Archives/edgar/data/168754...
# 2  https://www.sec.gov/Archives/edgar/data/113847...
# 3  https://www.sec.gov/Archives/edgar/data/195871...
# 4  https://www.sec.gov/Archives/edgar/data/175187...
#
#                                  filing_document_url
# 0  https://www.sec.gov/Archives/edgar/data/177619...
# 1  https://www.sec.gov/Archives/edgar/data/168754...
# 2  https://www.sec.gov/Archives/edgar/data/113847...
# 3  https://www.sec.gov/Archives/edgar/data/195871...
# 4  https://www.sec.gov/Archives/edgar/data/175187...

# %% [markdown]
# Let's explore some filings

# %%
import sovai as sov
nflx_filing = sov.sec_filing("NFLX", "10-Q", "2022-06-06")
# Out:
# INFO:rich:Identity of the Edgar REST client set to [Josh Stiela josh.stiel@factset.com]

# %%
nflx_filing.report
# Out:
#             <div class="sec-report dark">
#                 <style>
#                     .sec-report { font-family: Arial, sans-serif; }
#                     .sec-report.dark { background-color: #1a1a1a; color: #e0e0e0; }
#                     .sec-report-details { border: 1px solid #ccc; border-radius: 4px; margin-bottom: 1rem; }
#                     .sec-report-summary {
#                         cursor: pointer;
#                         padding: 1rem;
#                         background-color: #f0f0f0;
#                         font-weight: bold;
#                         user-select: none;
#                     }
#                     .sec-report.dark .sec-report-summary { background-color: #333; color: #fff; }
#                     .sec-report-summary:hover { background-color: #e0e0e0; }
#                     .sec-report.dark .sec-report-summary:hover { background-color: #444; }
#                     .sec-report-content { padding: 1rem; }
#                     .sec-report.dark .sec-report-content { background-color: #1a1a1a; }
#                 </style>
#
#             <details class="sec-report-details">
#                 <summary class="sec-report-summary">View SEC Report</summary>
#                 <div class="sec-report-content">
#
#             <style>
#                 .financial-statement {
#                     background-color: #1a1a1a !important;
#                     color: #e0e0e0 !important;
#                 }
#                 .financial-statement table {
#                     border-color: #444 !important;
#                 }
#                 .financial-statement th {
#                     background-color: #2c2c2c !important;
#                     color: #ffffff !important;
#                 }
#                 .financial-statement tr:nth-child(even) { background-color: #242424 !important; }
#                 .financial-statement tr:nth-child(odd) { background-color: #1e1e1e !important; }
#                 .financial-statement .text, .financial-statement .text-4, .financial-statement .text-5, .financial-statement .text-6, .financial-statement .page-heading { color: #ffffff !important; }
#                 .financial-statement [style*="color"] { color: #e0e0e0 !important; }
#                 .financial-statement [style*="background-color"] { background-color: transparent !important; }
#                 .financial-statement .financial-positive { color: #4caf50 !important; }
#                 .financial-statement .financial-negative { color: #f44336 !important; }
#                 .financial-statement .highlight { background-color: #3d3d3d !important; color: #ffffff !important; }
#                 .financial-statement table, .financial-statement th, .financial-statement td {
#                     border-color: #ffffff !important;
#                 }
#                 .financial-statement td[style*="border-bottom"],
#                 .financial-statement td[style*="border-top"],
#                 .financial-statement td[style*="border-left"],
#                 .financial-statement td[style*="border-right"] {
#                     border-color: #ffffff !important;
#                 }
#                 .financial-statement td[style*="border"] {
#                     border-color: #ffffff !important;
#                 }
#             </style>
#             <div class="financial-statement"><?xml version="1.0" ?><!--XBRL Document Created with Wdesk from Workiva--><!--Copyright 2022 Workiva--><!--r:346ede86-9937-4a8b-8516-200ecde38699,g:be415760-e57f-42a9-9975-1aae2c005a99,d:00c724b1d94a40e7a921c62ffcbed64b--><html xmlns:ix="http://www.xbrl.org/2013/inlineXBRL" xmlns:xbrli="http://www.xbrl.org/2003/instance" xmlns:link="http://www.xbrl.org/2003/linkbase" xmlns:srt="http://fasb.org/srt/2022" xmlns:ixt-sec="http://www.sec.gov/inlineXBRL/transformation/2015-08-31" xmlns:nflx="http://www.netflix.com/20220630" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:us-gaap="http://fasb.org/us-gaap/2022" xmlns:ixt="http://www.xbrl.org/inlineXBRL/transformation/2020-02-12" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xbrldi="http://xbrl.org/2006/xbrldi" xmlns:country="http://xbrl.sec.gov/country/2022" xmlns:iso4217="http://www.xbrl.org/2003/iso4217" xmlns="http://www.w3.org/1999/xhtml" xmlns:dei="http://xbrl.sec.gov/dei/2022" xml:lang="en-US"><head><meta http-equiv="Content-Type" content="text/html"/>
#
#
# <title>nflx-20220630</title></head><body><div style="display:none"><ix:header><ix:hidden><ix:nonNumeric contextRef="i1afdbdf680654904bf523d5e2bd9b51f_D20220101-20220630" name="dei:EntityCentralIndexKey" id="_63b2820f-c2bc-4085-ad8a-0178e367d2c2">0001065280</ix:nonNumeric><ix:nonNumeric contextRef="i1afdbdf680654904bf523d5e2bd9b51f_D20220101-20220630" name="dei:DocumentFiscalYearFocus" id="_c54d6e34-61d3-4576-83ff-573cda15eeff">2022</ix:nonNumeric><ix:nonNumeric contextRef="i1afdbdf680654904bf523d5e2bd9b51f_D20220101-20220630" name="dei:DocumentFiscalPeriodFocus" id="_1a6e3b1d-e069-4092-bf1d-da6cea4537a7">Q2</ix:nonNumeric><ix:nonNumeric contextRef="i1afdbdf680654904bf523d5e2bd9b51f_D20220101-20220630" name="dei:AmendmentFlag" format="ixt:fixed-false" id="_5a770528-5d05-4ed2-b3ea-64b0f1241d9b">false</ix:nonNumeric><ix:nonNumeric contextRef="i1afdbdf680654904bf523d5e2bd9b51f_D20220101-20220630" name="dei:CurrentFiscalYearEndDate" id="_40487959-e7c5-4150-9c16-1ee4cbbd42f9">--12-31</ix:nonNumeric><ix:nonNumeric contextRef="i6786c477a226434aa28456f750b0a760_I20211231" name="us-gaap:OperatingLeaseRightOfUseAssetStatementOfFinancialPositionExtensibleList" id="_047b9125-d61b-4f90-8c46-80daad466f87">http://fasb.org/us-gaap/2022#OtherAssetsNoncurrent</ix:nonNumeric><ix:nonNumeric contextRef="iad261c6bf8cf412e9d3068c56bd18e98_I20220630" name="us-gaap:OperatingLeaseRightOfUseAssetStatementOfFinancialPositionExtensibleList" id="_79480b44-fec2-4b89-bf2f-90f63dc42b23">http://fasb.org/us-gaap/2022#OtherAssetsNoncurrent</ix:nonNumeric><ix:nonNume

# %%
nflx_filing.balance_sheet
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                         Netflix, Inc. Balance Sheet Q2 2022
#
#                                                     2022-06-30         2021-12-31
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   ASSETS:
#   CURRENT ASSETS:
#     Cash and Cash Equivalents                    5,819,449,000      6,027,804,000
#     Other Current Assets                         2,021,329,000      2,042,021,000
#     Total Current Assets                         7,840,778,000      8,069,825,000
#
#   NONCURRENT ASSETS:
#     Property and Equipment, net                  1,361,920,000      1,323,453,000
#     Other Long-Term Assets                       4,615,038,000      4,271,846,000
#   Total Assets                                  46,350,935,000     44,584,663,000
#
#   LIABILITIES AND STOCKHOLDERS' EQUITY:
#   CURRENT LIABILITIES:
#     Accounts Payable                               504,278,000        837,483,000
#     Deferred Revenue                             1,224,743,000      1,209,342,000
#     Accrued Liabilities                          1,596,035,000      1,449,351,000
#     Total Current Liabilities                    7,500,022,000      8,488,966,000
#
#   NONCURRENT LIABILITIES:
#     Non-current Long Term Debt                  14,233,303,000     14,693,072,000
#     Other Long-Term Liabilities                  2,551,675,000      2,459,164,000
#   Total Liabilities                             27,274,961,000     28,735,415,000
#
#   STOCKHOLDERS' EQUITY:
#     Common Stock, shares issued                    444,705,591        443,963,107
#     Common Stock                                 4,316,870,000      4,024,561,000
#     Retained Earnings                           15,727,770,000     12,689,372,000
#     Accumulated Other Comprehensive Income        -144,476,000        -40,495,000
#     Total Stockholders' Equity                  19,075,974,000     15,849,248,000
#
#   Total Liabilities and Stockholders Equity     46,350,935,000     44,584,663,000

# %%
nflx_filing.income_statement
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#           Netflix, Inc. Consolidated Statement of Operations Q2 2022
#
#                                                2022-06-30         2021-06-30
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   SALES:
#   Revenue                                   7,970,141,000      7,341,777,000
#
#   COST OF SALES:
#     Cost of Revenue                         4,690,755,000      4,018,008,000
#   OPERATING EXPENSES:
#     Research & Development Expenses           716,846,000        537,321,000
#     Marketing Expense                         574,960,000        603,973,000
#     General & Administrative Expenses         409,297,000        334,845,000
#   Operating Income                          1,578,283,000      1,847,630,000
#
#   OTHER INCOME/EXPENSE:
#     Interest Expense                          175,455,000        191,322,000
#     Nonoperating Income                       220,226,000        -62,519,000
#   Income Before Taxes                       1,623,054,000      1,593,789,000
#
#   Income Tax Expense                          182,103,000        240,776,000
#   Net Income                                1,440,951,000      1,353,013,000
#
#   EARNINGS PER SHARE:
#     Basic                                            3.24               3.05
#     Diluted                                          3.20               2.97
#   WEIGHTED AVERAGE SHARES OUTSTANDING:
#     Basic                                     444,557,000        443,159,000
#     Diluted                                   450,169,000        455,129,000

# %%
nflx_filing.cash_flow_statement
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                        Netflix, Inc. Cashflow Statement Q2 2022
#
#                                                        2022-06-30         2021-06-30
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   OPERATING ACTIVITIES:
#     Net Income                                      1,440,951,000      1,353,013,000
#     Depreciation and Amortization                      83,505,000         38,434,000
#     Stock-based Compensation                          150,392,000        101,583,000
#     Foreign Currency Transaction Gain/Loss            304,513,000        -63,074,000
#     Other Noncash Income/Expense                     -205,374,000       -108,103,000
#     Changes in Other Current Assets                  -123,399,000         52,373,000
#     Changes in Accounts Payable                      -122,048,000         72,313,000
#     Changes in Deferred Revenue                       -10,376,000         47,093,000
#     Net Cash From Operating Activities                102,750,000        -63,761,000
#
#   INVESTING ACTIVITIES:
#     Purchases of Property, Plant and Equipment         90,018,000        110,278,000
#     Payments to Acquire Businesses                     68,876,000                  0
#     Deferred Revenue                                  -10,376,000         47,093,000
#     Other Investing Activities                                  0          1,000,000
#     Net Cash From Investing Activities               -158,894,000       -111,278,000
#
#   FINANCING ACTIVITIES:
#     Repurchases of Common Stock                                 0        500,022,000
#     Repayments of Long-term Debt                                0                  0
#     Net Cash From Financing Activities                 11,250,000       -480,273,000
#
#   Changes in Cash and Cash equivalents               -190,092,000       -631,835,000
#   Cash, cash equivalents and restricted cash        5,844,409,000

# %%
nflx_filing.sampled_facts
# Out:
# date                                                   2015-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                      190567000.000
# AccruedLiabilitiesCurrent_us-gaap                   107323000.000
# AccumulatedDepreciationDepletionAndAmortization...  277239000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -4446000.000
# AssetsCurrent_us-gaap                              3940469000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     204880.000
# StockholdersEquity_us-gaap                         1857708000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 5800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   61973000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   59817000.000
#
# date                                                   2015-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                      211729000.000
# AccruedLiabilitiesCurrent_us-gaap                    69746000.000
# AccumulatedDepreciationDepletionAndAmortization...  264816000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -38120000.000
# AssetsCurrent_us-gaap                              5600510000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...    3093944.000
# StockholdersEquity_us-gaap                         1857708000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 5700000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  431441000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  424486000.000
#
# date                                                   2015-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                      209365000.000
# AccruedLiabilitiesCurrent_us-gaap                   179350000.000
# AccumulatedDepreciationDepletionAndAmortization...  264816000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -4446000.000
# AssetsCurrent_us-gaap                              5569713000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...    4477401.000
# StockholdersEquity_us-gaap                         2167318000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 5800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  432742000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  426869000.000
#
# date                                                   2016-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                      253491000.000
# AccruedLiabilitiesCurrent_us-gaap                   140389000.000
# AccumulatedDepreciationDepletionAndAmortization...  305247000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -34401000.000
# AssetsCurrent_us-gaap                              5431840000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     348776.000
# StockholdersEquity_us-gaap                         2317233000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 6600000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  433809000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  428117000.000
#
# date                                                   2016-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                      240458000.000
# AccruedLiabilitiesCurrent_us-gaap                   140389000.000
# AccumulatedDepreciationDepletionAndAmortization...  311345000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -43308000.000
# AssetsCurrent_us-gaap                              5386918000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     784948.000
# StockholdersEquity_us-gaap                         2223426000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 6100000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  434958000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  424486000.000
#
# date                                                   2016-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                      253491000.000
# AccruedLiabilitiesCurrent_us-gaap                   140389000.000
# AccumulatedDepreciationDepletionAndAmortization...  297346000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -36530000.000
# AssetsCurrent_us-gaap                              5431840000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...    1204583.000
# StockholdersEquity_us-gaap                         2528966000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 6100000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  435849000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  425289000.000
#
# date                                                   2017-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                      294831000.000
# AccruedLiabilitiesCurrent_us-gaap                   296258000.000
# AccumulatedDepreciationDepletionAndAmortization...  294209000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -45859000.000
# AssetsCurrent_us-gaap                              5720291000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     939217.000
# StockholdersEquity_us-gaap                         2679800000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 8000000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  445458000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  428117000.000
#
# date                                                   2017-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                      312842000.000
# AccruedLiabilitiesCurrent_us-gaap                   197632000.000
# AccumulatedDepreciationDepletionAndAmortization...  294209000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -48565000.000
# AssetsCurrent_us-gaap                              5720291000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...    1695532.000
# StockholdersEquity_us-gaap                         3112500000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 8200000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  446262000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  431396000.000
#
# date                                                   2017-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                      312842000.000
# AccruedLiabilitiesCurrent_us-gaap                   197632000.000
# AccumulatedDepreciationDepletionAndAmortization...  294209000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -48565000.000
# AssetsCurrent_us-gaap                              6385348000.000
# ...                                                           ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...    2676918.000
# StockholdersEquity_us-gaap                         3327361000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 8000000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...  447362000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...  428514000.000
#
# date                                                    2018-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                       436183000.000
# AccruedLiabilitiesCurrent_us-gaap                    315094000.000
# AccumulatedDepreciationDepletionAndAmortization...   337866000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...     4264000.000
# AssetsCurrent_us-gaap                               7817576000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     1264617.000
# StockholdersEquity_us-gaap                          3581956000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 10200000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   450359000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   430600000.000
#
# date                                                    2018-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       359555000.000
# AccruedLiabilitiesCurrent_us-gaap                    315094000.000
# AccumulatedDepreciationDepletionAndAmortization...   321814000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -12427000.000
# AssetsCurrent_us-gaap                               9346889000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     2064819.000
# StockholdersEquity_us-gaap                          3581956000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 10300000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   445862000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   435097000.000
#
# date                                                    2018-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       359555000.000
# AccruedLiabilitiesCurrent_us-gaap                    315094000.000
# AccumulatedDepreciationDepletionAndAmortization...   321814000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -14508000.000
# AssetsCurrent_us-gaap                               7669974000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     2692309.000
# StockholdersEquity_us-gaap                          5009653000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 10200000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   451283000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   432404000.000
#
# date                                                    2019-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                       439496000.000
# AccruedLiabilitiesCurrent_us-gaap                    746268000.000
# AccumulatedDepreciationDepletionAndAmortization...   368519000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -19582000.000
# AssetsCurrent_us-gaap                               4168907000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      593294.000
# StockholdersEquity_us-gaap                          3581956000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 10400000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   451922000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   434174000.000
#
# date                                                    2019-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       562985000.000
# AccruedLiabilitiesCurrent_us-gaap                    750812000.000
# AccumulatedDepreciationDepletionAndAmortization...   368519000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -19582000.000
# AssetsCurrent_us-gaap                               9694135000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     1236285.000
# StockholdersEquity_us-gaap                          6105548000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 10100000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   452063000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   434638000.000
#
# date                                                    2019-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       562985000.000
# AccruedLiabilitiesCurrent_us-gaap                   1037723000.000
# AccumulatedDepreciationDepletionAndAmortization...   402604000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -19582000.000
# AssetsCurrent_us-gaap                               9694135000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     1652692.000
# StockholdersEquity_us-gaap                          6861505000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 10800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   451283000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   435809000.000
#
# date                                                    2020-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                       674347000.000
# AccruedLiabilitiesCurrent_us-gaap                    843043000.000
# AccumulatedDepreciationDepletionAndAmortization...   436556000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -23521000.000
# AssetsCurrent_us-gaap                               6447781000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      973969.000
# StockholdersEquity_us-gaap                          5238765000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 11800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   451922000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   439352000.000
#
# date                                                    2020-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       446668000.000
# AccruedLiabilitiesCurrent_us-gaap                    986595000.000
# AccumulatedDepreciationDepletionAndAmortization...   460206000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -23521000.000
# AssetsCurrent_us-gaap                               6178504000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     2208741.000
# StockholdersEquity_us-gaap                          7582157000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 11800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   453220000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   437587000.000
#
# date                                                    2020-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       674347000.000
# AccruedLiabilitiesCurrent_us-gaap                    843043000.000
# AccumulatedDepreciationDepletionAndAmortization...   416005000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...    -1147000.000
# AssetsCurrent_us-gaap                               9826480000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     2988359.000
# StockholdersEquity_us-gaap                          9334753000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 11800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   451896000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   438090000.000
#
# date                                                    2021-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                       532942000.000
# AccruedLiabilitiesCurrent_us-gaap                   1102196000.000
# AccumulatedDepreciationDepletionAndAmortization...   520544000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...    44398000.000
# AssetsCurrent_us-gaap                               9761580000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      488471.000
# StockholdersEquity_us-gaap                         12884080000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 13900000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   455641000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   439352000.000
#
# date                                                    2021-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       622931000.000
# AccruedLiabilitiesCurrent_us-gaap                   1125591000.000
# AccumulatedDepreciationDepletionAndAmortization...   552965000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...    44398000.000
# AssetsCurrent_us-gaap                               9761580000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      702192.000
# StockholdersEquity_us-gaap                         12884080000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 15400000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   453220000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   440569000.000
#
# date                                                    2021-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       656183000.000
# AccruedLiabilitiesCurrent_us-gaap                   1413120000.000
# AccumulatedDepreciationDepletionAndAmortization...   494790000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -19835000.000
# AssetsCurrent_us-gaap                               9761580000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     1239343.000
# StockholdersEquity_us-gaap                         15314617000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 16100000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   453846000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   440486000.000
#
# date                                                    2022-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                       617202000.000
# AccruedLiabilitiesCurrent_us-gaap                   1817117000.000
# AccumulatedDepreciationDepletionAndAmortization...   616306000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -40495000.000
# AssetsCurrent_us-gaap                               8069825000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      310743.000
# StockholdersEquity_us-gaap                         12884080000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 15800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   452984000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   444146000.000
#
# date                                                    2022-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       837483000.000
# AccruedLiabilitiesCurrent_us-gaap                   1596035000.000
# AccumulatedDepreciationDepletionAndAmortization...   616306000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -144476000.000
# AssetsCurrent_us-gaap                               8069825000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      742484.000
# StockholdersEquity_us-gaap                         11065240000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 15600000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   455385000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   443159000.000
#
# date                                                    2022-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       837483000.000
# AccruedLiabilitiesCurrent_us-gaap                   1803555000.000
# AccumulatedDepreciationDepletionAndAmortization...   616306000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -247643000.000
# AssetsCurrent_us-gaap                               8816903000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     1057387.000
# StockholdersEquity_us-gaap                         11065240000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 15800000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   454925000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   444878000.000
#
# date                                                    2023-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                       591987000.000
# AccruedLiabilitiesCurrent_us-gaap                   1718069000.000
# AccumulatedDepreciationDepletionAndAmortization...   753741000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -191695000.000
# AssetsCurrent_us-gaap                               9266473000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      412158.000
# StockholdersEquity_us-gaap                         20777401000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 14300000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   452417000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   445244000.000
#
# date                                                    2023-06-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       615374000.000
# AccruedLiabilitiesCurrent_us-gaap                   1514650000.000
# AccumulatedDepreciationDepletionAndAmortization...   870738000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -217306000.000
# AssetsCurrent_us-gaap                              11506336000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...      871355.000
# StockholdersEquity_us-gaap                         19075974000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 13700000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   450169000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   443881000.000
#
# date                                                    2023-09-30  \
# unique_id
# AccountsPayableCurrent_us-gaap                       671513000.000
# AccruedLiabilitiesCurrent_us-gaap                   1838908000.000
# AccumulatedDepreciationDepletionAndAmortization...   753741000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -155571000.000
# AssetsCurrent_us-gaap                               9266473000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     1369075.000
# StockholdersEquity_us-gaap                         20777401000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 12700000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   450011000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   444878000.000
#
# date                                                    2024-03-31  \
# unique_id
# AccountsPayableCurrent_us-gaap                       607348000.000
# AccruedLiabilitiesCurrent_us-gaap                   1803960000.000
# AccumulatedDepreciationDepletionAndAmortization...   884603000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -223945000.000
# AssetsCurrent_us-gaap                               9921313000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     1768956.000
# StockholdersEquity_us-gaap                         20777401000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 14600000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   441654000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   445244000.000
#
# date                                                    2024-06-30
# unique_id
# AccountsPayableCurrent_us-gaap                       598557000.000
# AccruedLiabilitiesCurrent_us-gaap                   1803960000.000
# AccumulatedDepreciationDepletionAndAmortization...   855043000.000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...  -223945000.000
# AssetsCurrent_us-gaap                               9918133000.000
# ...                                                            ...
# StockIssuedDuringPeriodSharesStockOptionsExerci...     2543267.000
# StockholdersEquity_us-gaap                         22112693000.000
# UnrecordedUnconditionalPurchaseObligationBalanc... 16900000000.000
# WeightedAverageNumberOfDilutedSharesOutstanding...   451990000.000
# WeightedAverageNumberOfSharesOutstandingBasic_u...   443881000.000
#
# [66 rows x 29 columns]

# %%
nflx_filing.plot_facts
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
