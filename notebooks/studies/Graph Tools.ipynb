# %%
# !pip install sovai[full]

# %%
# !pip install edgartools==2.27.5

# %%
import sovai as sov

sov.token_auth(token="visit https://sov.ai/profile for your token")

sov.data("sec/10k",tickers=["NVDA"])
# Out:
#      ticker       date      company      cik      accession_number   section  \
# 0      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 1      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 2      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 3      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 4      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# ...     ...        ...          ...      ...                   ...       ...
# 6596   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6597   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6598   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6599   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6600   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
#
#       order       category   tag                            row_id  \
# 0         0  NarrativeText  font  d0d6d6458ad65b3d98a53c2865a30a10
# 1         1  NarrativeText  font  12edce37a67edb44f429f12cc4d31214
# 2         2  NarrativeText  font  57fc43f1b58acfd824a3737ee1de2fde
# 3         3  NarrativeText  font  2210ff778d1be92de112b67f3105ca81
# 4         4  NarrativeText  font  594745fd99a88246333c82451aefa8fc
# ...     ...            ...   ...                               ...
# 6596    266  NarrativeText    td  7edd1e47092085a992221c107eda0e08
# 6597    267       ListItem   div  ef53ee4dc7ffe7c040bd5ee7233a9778
# 6598    268  NarrativeText  span  9b8e9e47a1be19a338ab2141b66e2cfe
# 6599    269  NarrativeText  span  de3b672614c78814d4a3f6ab8e5adc88
# 6600    270  NarrativeText  span  a2432559cb9f0e6f3b3a48300a90c23e
#
#                                               full_text
# 0     This Annual Report on Form 10-K contains forwa...
# 1     All references to “NVIDIA,” “we,” “us,” “our” ...
# 2     © 2011 NVIDIA Corporation. All rights reserved...
# 3     NVIDIA Corporation invented the graphics proce...
# 4     We have three primary financial reporting segm...
# ...                                                 ...
# 6596     Power of Attorney (included in signature page)
# 6597                                    Filed herewith.
# 6598  # In accordance with Item 601(b)(32)(ii) of Re...
# 6599  ^ Certain exhibits and schedules have been omi...
# 6600  Copies of above exhibits not contained herein ...
#
# [6601 rows x 11 columns]

# %%
data = sov.data("sec/10k",columns=["ticker","date","full_text"])

# %%
data.info()
# Out:
# <class 'sovai.extensions.pandas_extensions.CustomDataFrame'>
# RangeIndex: 1344413 entries, 0 to 1344412
# Data columns (total 3 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   ticker     1344413 non-null  object
#  1   date       1344413 non-null  datetime64[ns]
#  2   full_text  1344413 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 30.8+ MB

# %%
data["ticker"].value_counts()
# Out:
# ticker
# 8192     36409
# 79732    36409
# 27879    36409
# 9466     34966
# 22606    29905
#          ...
# 77227       17
# 65350       17
# 40528       17
# 42284       11
# 30419        7
# Name: count, Length: 288, dtype: int64

# %%
df_codes = pd.read_parquet("data/codes.parq")

# %%
df_codes.query("ticker =='NVDA'")
# Out:
#      ticker ticker_1 ticker_2 ticker_3 ticker_4      cusip cusip_1  \
# 3567   NVDA  NVDARUB      NVI    4NVDA  NVDACHF  67066G104    None
#
#              cik top_level_openfigi_id isdelisted         name
# 3567  0001045810          BBG001S5TZJ6          N  NVIDIA CORP

# %%
sov.data("sec/10k",tickers=["NVDA"])
# Out:
#      ticker       date      company      cik      accession_number   section  \
# 0      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 1      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 2      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 3      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# 4      NVDA 2011-03-16  NVIDIA CORP  1045810  0001045810-11-000015  BUSINESS
# ...     ...        ...          ...      ...                   ...       ...
# 6596   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6597   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6598   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6599   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
# 6600   NVDA 2024-02-21  NVIDIA CORP  1045810  0001045810-24-000029  EXHIBITS
#
#       order       category   tag                            row_id  \
# 0         0  NarrativeText  font  d0d6d6458ad65b3d98a53c2865a30a10
# 1         1  NarrativeText  font  12edce37a67edb44f429f12cc4d31214
# 2         2  NarrativeText  font  57fc43f1b58acfd824a3737ee1de2fde
# 3         3  NarrativeText  font  2210ff778d1be92de112b67f3105ca81
# 4         4  NarrativeText  font  594745fd99a88246333c82451aefa8fc
# ...     ...            ...   ...                               ...
# 6596    266  NarrativeText    td  7edd1e47092085a992221c107eda0e08
# 6597    267       ListItem   div  ef53ee4dc7ffe7c040bd5ee7233a9778
# 6598    268  NarrativeText  span  9b8e9e47a1be19a338ab2141b66e2cfe
# 6599    269  NarrativeText  span  de3b672614c78814d4a3f6ab8e5adc88
# 6600    270  NarrativeText  span  a2432559cb9f0e6f3b3a48300a90c23e
#
#                                               full_text
# 0     This Annual Report on Form 10-K contains forwa...
# 1     All references to “NVIDIA,” “we,” “us,” “our” ...
# 2     © 2011 NVIDIA Corporation. All rights reserved...
# 3     NVIDIA Corporation invented the graphics proce...
# 4     We have three primary financial reporting segm...
# ...                                                 ...
# 6596     Power of Attorney (included in signature page)
# 6597                                    Filed herewith.
# 6598  # In accordance with Item 601(b)(32)(ii) of Re...
# 6599  ^ Certain exhibits and schedules have been omi...
# 6600  Copies of above exhibits not contained herein ...
#
# [6601 rows x 11 columns]

# %%
from sovai.utils.client_side_s3 import load_frame_s3

# %%
full_frame = load_frame_s3("sec/10k", tickers=["TSLA"])

# %%
full_frame
# Out:
#       ticker       date           company      cik      accession_number  \
# 0       TSLA 2011-03-03  TESLA MOTORS INC  1318605  0001193125-11-054847
# 1       TSLA 2011-03-03  TESLA MOTORS INC  1318605  0001193125-11-054847
# 2       TSLA 2011-03-03  TESLA MOTORS INC  1318605  0001193125-11-054847
# 3       TSLA 2011-03-03  TESLA MOTORS INC  1318605  0001193125-11-054847
# 4       TSLA 2011-03-03  TESLA MOTORS INC  1318605  0001193125-11-054847
# ...      ...        ...               ...      ...                   ...
# 12356   TSLA 2024-01-29       Tesla, Inc.  1318605  0001628280-24-002390
# 12357   TSLA 2024-01-29       Tesla, Inc.  1318605  0001628280-24-002390
# 12358   TSLA 2024-01-29       Tesla, Inc.  1318605  0001628280-24-002390
# 12359   TSLA 2024-01-29       Tesla, Inc.  1318605  0001628280-24-002390
# 12360   TSLA 2024-01-29       Tesla, Inc.  1318605  0001628280-24-002390
#
#                        section  order       category   tag  \
# 0                     BUSINESS      0  NarrativeText     p
# 1                     BUSINESS      1  NarrativeText     p
# 2                     BUSINESS      2  NarrativeText     p
# 3                     BUSINESS      3  NarrativeText     p
# 4                     BUSINESS      4  NarrativeText     p
# ...                        ...    ...            ...   ...
# 12356  CONTROLS_AND_PROCEDURES      4  NarrativeText  span
# 12357  CONTROLS_AND_PROCEDURES      5  NarrativeText  span
# 12358  CONTROLS_AND_PROCEDURES      6  NarrativeText  span
# 12359             COMPENSATION      0  NarrativeText  span
# 12360   PRINCIPAL_STOCKHOLDERS      0  NarrativeText  span
#
#                                  row_id  \
# 0      80d45229e311eff98b21c61be0fc6947
# 1      eeffae10c5ca775920111aa6d8e63ada
# 2      75bde03bf85f0527af876b85849e0e04
# 3      cce922556b786e2e9b5a48dd1ec89118
# 4      6ddcb1fefd5fee7921c5ca6ee35e426c
# ...                                 ...
# 12356  1a58273224ac831216a479e1d03c2909
# 12357  5ac959d5b171db5cd209309402efda04
# 12358  ff807593c2468e087a4d1fbba5037302
# 12359  ee3dd47f541b8a3204cd707cba5806e9
# 12360  937eaf3426e0cc684f97a13a17b7dccb
#
#                                                full_text
# 0      We design,\ndevelop, manufacture and sell high...
# 1      We are the first company to commercially produ...
# 2      The commercial production of a highway capable...
# 3      We sell and service our Tesla Roadster though ...
# 4      Our first vehicle, the Tesla Roadster, can acc...
# ...                                                  ...
# 12356  Our independent registered public accounting f...
# 12357  Because of inherent limitations, internal cont...
# 12358  There was no change in our internal control ov...
# 12359  The information required by this Item 11 of Fo...
# 12360  The information required by this Item 12 of Fo...
#
# [12361 rows x 11 columns]

# %%
full_frame[full_frame["cik"]==8192]
# Out:
#        ticker       date                    company   cik  \
# 262902   8192 2005-03-16  ATLANTIC CITY ELECTRIC CO  8192
# 262903   8192 2005-03-16  ATLANTIC CITY ELECTRIC CO  8192
# 262904   8192 2005-03-16  ATLANTIC CITY ELECTRIC CO  8192
# 262905   8192 2005-03-16  ATLANTIC CITY ELECTRIC CO  8192
# 262906   8192 2005-03-16  ATLANTIC CITY ELECTRIC CO  8192
# ...       ...        ...                        ...   ...
# 299306   8192 2024-02-21  ATLANTIC CITY ELECTRIC CO  8192
# 299307   8192 2024-02-21  ATLANTIC CITY ELECTRIC CO  8192
# 299308   8192 2024-02-21  ATLANTIC CITY ELECTRIC CO  8192
# 299309   8192 2024-02-21  ATLANTIC CITY ELECTRIC CO  8192
# 299310   8192 2024-02-21  ATLANTIC CITY ELECTRIC CO  8192
#
#             accession_number   section  order       category   tag  \
# 262902  0001135971-05-000100  BUSINESS      0  NarrativeText    td
# 262903  0001135971-05-000100  BUSINESS      1       ListItem    tr
# 262904  0001135971-05-000100  BUSINESS      2       ListItem    tr
# 262905  0001135971-05-000100  BUSINESS      3       ListItem    tr
# 262906  0001135971-05-000100  BUSINESS      4  NarrativeText    td
# ...                      ...       ...    ...            ...   ...
# 299306  0001109357-24-000053  EXHIBITS     98  NarrativeText    td
# 299307  0001109357-24-000053  EXHIBITS     99  NarrativeText    td
# 299308  0001109357-24-000053  EXHIBITS    100  NarrativeText    td
# 299309  0001109357-24-000053  EXHIBITS    101       ListItem   div
# 299310  0001109357-24-000053  EXHIBITS    102  NarrativeText  span
#
#                                   row_id  \
# 262902  f2acda0a860bb7d5bf8b6fff1c9ba91b
# 262903  e8aeccd2a6d73c91be151591055efdd0
# 262904  129ffb48a38ee25887de5abf72e93b83
# 262905  bdc9aea9ee7cfecbaed4c68c8b18f2b0
# 262906  0b2cc4b5e1ecb860fad50f8465325227
# ...                                  ...
# 299306  01a480d380c4754a98fdbd02a4eef2c6
# 299307  9de377b3bcbe1e8bd26454bb7972b7d0
# 299308  2ae0b8f20fb2808e2325ed72579b7ce1
# 299309  edc6c4a99a0c9309546d04b84b5c8046
# 299310  169ecffe7795b60a466f621808481acf
#
#                                                 full_text
# 262902  Pepco Holdings, Inc. (Pepco Holdings or PHI) i...
# 262903    regulated electricity and natural gas delivery,
# 262904  competitive energy generation, marketing and s...
# 262905  other activities consisting primarily of inves...
# 262906  PHI is a public utility holding company regist...
# ...                                                   ...
# 299306  Credit Agreement for $900,000,000 dated Februa...
# 299307  Letter Agreement, dated June 4, 2020, between ...
# 299308  Certifications Pursuant to Rule 13a-14(a) and ...
# 299309  Compensatory plan or arrangements in which dir...
# 299310  These filings are not available electronically...
#
# [36409 rows x 11 columns]

# %%
full_frame["cik"].value_counts()
# Out:
# cik
# 8192     36409
# 9466     34966
# 18672    26949
# 4515     16464
# 9346     15352
#          ...
# 15393      254
# 15310      186
# 6571       125
# 13573      115
# 3982        79
# Name: count, Length: 68, dtype: int64

# %%
# %%timeit
map_identifier(["AMZN","NVDA","MSFT"])
# Out:
# 7.05 ms ± 187 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import pyarrow.dataset as ds
from pyarrow.fs import S3FileSystem
import pyarrow as pa
import pandas as pd
from functools import lru_cache
from concurrent.futures import ThreadPoolExecutor, as_completed
from sovai.tools.authentication import authentication


@lru_cache(maxsize=2)
def get_cached_s3_filesystem(storage_provider):
    return authentication.get_s3_filesystem_pickle(storage_provider, verbose=True)

def process_partition(storage_provider, base_path, identifier_column, identifier=None, columns=None, filters=None):
    s3 = get_cached_s3_filesystem(storage_provider)
    
    if identifier:
        base_path += f"/{identifier_column}={identifier}"
    
    dataset = ds.dataset(base_path, filesystem=s3, format='parquet')
    
    if filters:
        operator_map = {
            '==': lambda a, b: a == b,
            '!=': lambda a, b: a != b,
            '<': lambda a, b: a < b,
            '<=': lambda a, b: a <= b,
            '>': lambda a, b: a > b,
            '>=': lambda a, b: a >= b,
            'in': lambda a, b: a.isin(b),
            'not in': lambda a, b: ~a.isin(b),
            'like': lambda a, b: a.match_substring(b),
        }
        schema = dataset.schema
        filter_expr = None
        for col, op, val in filters:
            if op not in operator_map:
                raise ValueError(f"Unsupported operator '{op}' in filters.")
            field = ds.field(col)
            field_type = schema.field(col).type
            if pa.types.is_timestamp(field_type) or pa.types.is_date(field_type):
                val = pd.to_datetime(val)
            elif pa.types.is_integer(field_type):
                val = int(val)
            elif pa.types.is_floating(field_type):
                val = float(val)
            condition = operator_map[op](field, val)
            filter_expr = condition if filter_expr is None else filter_expr & condition
    else:
        filter_expr = None
    
    table = dataset.to_table(columns=columns, filter=filter_expr, use_threads=True)
    df = table.to_pandas(use_threads=True)
    
    if identifier:
        df[identifier_column] = identifier
    
    return df

def client_side_s3_frame(config, identifiers, columns, start_date, end_date):
    storage_provider = "digitalocean"  # Default to DigitalOcean
    base_path = config["storage_provider"][storage_provider]
    identifier_column = config.get("identifier_column", "cik")
    
    filters = []
    if start_date:
        filters.append(('date', '>=', start_date))
    if end_date:
        filters.append(('date', '<=', end_date))

    if not identifiers:
        # Load the entire database
        return process_partition(storage_provider, base_path, identifier_column, columns=columns, filters=filters)
    
    if isinstance(identifiers, str) or (isinstance(identifiers, list) and len(identifiers) == 1):
        # Single identifier
        identifier = identifiers if isinstance(identifiers, str) else identifiers[0]
        return process_partition(storage_provider, base_path, identifier_column, identifier=identifier, columns=columns, filters=filters)
    
    # Multiple identifiers
    with ThreadPoolExecutor() as executor:
        futures = []
        for identifier in identifiers:
            futures.append(executor.submit(process_partition, storage_provider, base_path, identifier_column, identifier, columns, filters))
        
        results = []
        for future in as_completed(futures):
            results.append(future.result())
    
    df = pd.concat(results, ignore_index=True)
    # if 'filing_date' in df.columns:
    #     df['date'] = pd.to_datetime(df['filing_date'])
    # elif 'date' not in df.columns:
    #     raise ValueError("Neither 'filing_date' nor 'date' column found in the data")
    
    # df.set_index([identifier_column, 'date'], inplace=True)
    # df.sort_index(inplace=True)
    
    return df


def load_frame_s3(endpoint, identifiers, columns, start_date, end_date):

    endpoint_config = {
        "sec/10k": {
            "storage_provider": {
                "digitalocean": "sovai/sovai-filings/tenk",
                "wasabi": "sovai-filings/tenk"
            },
            "identifier_column": "cik",
            "partitioned": True,
        },
        "future/enpdoint": {
            "storage_provider": {
                "digitalocean": "sovai/sovai-filings/tenk",
                "wasabi": "sovai-filings/tenk"
            },
            "identifier_column": "cik",
            "partitioned": True,
        }
    }
    
    if endpoint not in endpoint_config:
        raise ValueError(f"Invalid endpoint: {endpoint}")
    
    config = endpoint_config[endpoint]
    
    if endpoint == "sec/10k":
        df_frame = client_side_s3_frame(
            config,
            identifiers,
            columns,
            start_date,
            end_date
        )
    else:
        # Implement logic for other endpoints if needed
        raise NotImplementedError(f"Endpoint {endpoint} is not yet implemented")
    
    if HAS_CUSTOM_DATAFRAME:
        return CustomDataFrame(df_frame)
    else:
        return df_frame  # Returns a regular pandas DataFrame if CustomDataFrame is not available

# %%
result
# Out:
#      ticker       date         company      cik      accession_number  \
# 0      NVDA 2020-02-20     NVIDIA CORP  1045810  0001045810-20-000010
# 1      NVDA 2020-02-20     NVIDIA CORP  1045810  0001045810-20-000010
# 2      NVDA 2020-02-20     NVIDIA CORP  1045810  0001045810-20-000010
# 3      NVDA 2020-02-20     NVIDIA CORP  1045810  0001045810-20-000010
# 4      NVDA 2020-02-20     NVIDIA CORP  1045810  0001045810-20-000010
# ...     ...        ...             ...      ...                   ...
# 5450   AMZN 2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 5451   AMZN 2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 5452   AMZN 2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 5453   AMZN 2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 5454   AMZN 2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
#
#            section  order       category   tag  \
# 0         BUSINESS      0  NarrativeText  span
# 1     RISK_FACTORS      0  NarrativeText  span
# 2     RISK_FACTORS      1  NarrativeText  span
# 3     RISK_FACTORS      2  NarrativeText  span
# 4     RISK_FACTORS      3  NarrativeText  span
# ...            ...    ...            ...   ...
# 5450      EXHIBITS     11  NarrativeText    td
# 5451      EXHIBITS     12  NarrativeText    td
# 5452      EXHIBITS     13  NarrativeText    td
# 5453      EXHIBITS     14  NarrativeText    td
# 5454      EXHIBITS     15  NarrativeText    td
#
#                                 row_id  \
# 0     e19d4ca0390b707fa28a6f3df94eee85
# 1     8c4ca624e6ba0ceadf036cd3e6298ea0
# 2     bf1a952bda530277faca60d35fb4d05c
# 3     a5504c57bbea76af4a334b40bf149596
# 4     0094cd1d5a9fa29571485d596bca69b1
# ...                                ...
# 5450  6e10005c9c5f296a4508772bfbd1b6e6
# 5451  9d7eb61ac35b6e8db69e310ff94bc022
# 5452  031fa93d31812a8a247bf7201f2dcbbc
# 5453  ce9cac19ce2ee676a5272d9ba1ac67e9
# 5454  88e11504afc87ab227540414cba9508b
#
#                                               full_text
# 0     Our worldwide operations could be disrupted by...
# 1     In evaluating NVIDIA and our business, the fol...
# 2     If we fail to meet the evolving needs of our m...
# 3     We created GPU-based visual and accelerated co...
# 4     Competition in our current and target markets ...
# ...                                                 ...
# 5450  Form of Indemnification Agreement between Amaz...
# 5451  Term Loan Agreement, dated as of January 3, 20...
# 5452  Five-Year Revolving Credit Agreement, dated as...
# 5453  364-Day Revolving Credit Agreement, dated as o...
# 5454  As permitted by Item 601(b)(4)(iii)(A) of Regu...
#
# [5455 rows x 11 columns]

# %%
# %%timeit
result = client_side_s3_frame(config, identifiers, columns, start_date, end_date)
# Out:
# 363 ms ± 7.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# client_side_s3.py
import pandas as pd
import pyarrow.dataset as ds
import pyarrow as pa
from pyarrow.fs import S3FileSystem
from functools import lru_cache
import sovai as sov
from sovai.tools.authentication import authentication
from concurrent.futures import ThreadPoolExecutor, as_completed

sov.token_auth(token="visit https://sov.ai/profile for your token")

@lru_cache(maxsize=2)
def get_cached_s3_filesystem(storage_provider):
    return authentication.get_s3_filesystem_pickle(storage_provider, verbose=True)

def process_s3_partition(storage_provider, base_path, identifier_column, identifier_value, columns=None, filters=None):
    s3 = get_cached_s3_filesystem(storage_provider)
    
    dataset = ds.dataset(base_path, filesystem=s3, format='parquet')
    
    if filters is None:
        filters = []
    filters.append((identifier_column, '==', identifier_value))
    
    operator_map = {
        '==': lambda a, b: a == b,
        '!=': lambda a, b: a != b,
        '<': lambda a, b: a < b,
        '<=': lambda a, b: a <= b,
        '>': lambda a, b: a > b,
        '>=': lambda a, b: a >= b,
        'in': lambda a, b: a.isin(b),
        'not in': lambda a, b: ~a.isin(b),
        'like': lambda a, b: a.match_substring(b),
    }
    
    schema = dataset.schema
    filter_expr = None
    for col, op, val in filters:
        if op not in operator_map:
            raise ValueError(f"Unsupported operator '{op}' in filters.")
        field = ds.field(col)
        field_type = schema.field(col).type
        if pa.types.is_timestamp(field_type) or pa.types.is_date(field_type):
            val = pd.to_datetime(val)
        elif pa.types.is_integer(field_type):
            val = int(val)
        elif pa.types.is_floating(field_type):
            val = float(val)
        condition = operator_map[op](field, val)
        filter_expr = condition if filter_expr is None else filter_expr & condition
    
    table = dataset.to_table(columns=columns, filter=filter_expr, use_threads=True)
    return table.to_pandas(use_threads=True)

def process_identifier(args):
    storage_provider, base_path, identifier_column, identifier, columns, filters = args
    df = process_s3_partition(storage_provider, base_path, identifier_column, identifier, columns, filters)
    if 'filing_date' in df.columns:
        df['date'] = pd.to_datetime(df['filing_date'])
    elif 'date' not in df.columns:
        raise ValueError(f"Neither 'filing_date' nor 'date' column found in the data for {identifier}")
    return df

def client_side_s3_frame(config, identifiers, columns, start_date, end_date):
    storage_provider = "digitalocean"  # Default to DigitalOcean
    base_path = config["storage_provider"][storage_provider]
    identifier_column = config.get("identifier_column", "cik")
    
    filters = []
    if start_date:
        filters.append(('filing_date', '>=', start_date))
    if end_date:
        filters.append(('filing_date', '<=', end_date))
    
    with ThreadPoolExecutor() as executor:
        futures = []
        for identifier in identifiers:
            args = (storage_provider, base_path, identifier_column, identifier, columns, filters)
            futures.append(executor.submit(process_identifier, args))
        
        results = []
        for future in as_completed(futures):
            results.append(future.result())
    
    df = pd.concat(results, ignore_index=True)
    df.set_index([identifier_column, 'date'], inplace=True)
    df.sort_index(inplace=True)
    
    return df


config = {
    "s3": True,
    "storage_provider": {
        "digitalocean": "sovai/sovai-filings/tenk",
        "wasabi": "sovai-filings/tenk"
    },
    "identifier_column": "cik"
}
identifiers = ["1018724"]  # Example CIKs
columns = None
start_date = "2020-01-01"
end_date = None

result = client_side_s3_frame(config, identifiers, columns, start_date, end_date)

# %%
result = client_side_s3_frame(config, identifiers, columns, start_date, end_date)

# %%
# client_side_s3.py
import pandas as pd
import pyarrow.dataset as ds
import pyarrow as pa
from pyarrow.fs import S3FileSystem
from functools import lru_cache
import sovai as sov
from sovai.tools.authentication import authentication

sov.token_auth(token="visit https://sov.ai/profile for your token")

@lru_cache(maxsize=2)
def get_cached_s3_filesystem(storage_provider):
    return authentication.get_s3_filesystem_pickle(storage_provider, verbose=True)

def process_s3_partition(storage_provider, base_path, identifier_column=None, identifier_values=None, columns=None, filters=None):
    s3 = get_cached_s3_filesystem(storage_provider)
    
    dataset = ds.dataset(base_path, filesystem=s3, format='parquet')
    
    if identifier_column and identifier_values:
        if filters is None:
            filters = []
        filters.append((identifier_column, 'in', identifier_values))
    
    if filters:
        operator_map = {
            '==': lambda a, b: a == b,
            '!=': lambda a, b: a != b,
            '<': lambda a, b: a < b,
            '<=': lambda a, b: a <= b,
            '>': lambda a, b: a > b,
            '>=': lambda a, b: a >= b,
            'in': lambda a, b: a.isin(b),
            'not in': lambda a, b: ~a.isin(b),
            'like': lambda a, b: a.match_substring(b),
        }
        schema = dataset.schema
        filter_expr = None
        for col, op, val in filters:
            if op not in operator_map:
                raise ValueError(f"Unsupported operator '{op}' in filters.")
            field = ds.field(col)
            field_type = schema.field(col).type
            if op not in ['in', 'not in']:
                if pa.types.is_timestamp(field_type) or pa.types.is_date(field_type):
                    val = pd.to_datetime(val)
                elif pa.types.is_integer(field_type):
                    val = int(val)
                elif pa.types.is_floating(field_type):
                    val = float(val)
            condition = operator_map[op](field, val)
            filter_expr = condition if filter_expr is None else filter_expr & condition
    else:
        filter_expr = None
    
    table = dataset.to_table(columns=columns, filter=filter_expr, use_threads=True)
    return table.to_pandas(use_threads=True)

def client_side_s3_frame(config, identifiers, columns, start_date, end_date):
    storage_provider = "digitalocean"  # Default to DigitalOcean
    base_path = config["storage_provider"][storage_provider]
    identifier_column = config.get("identifier_column", "cik")
    
    filters = []
    if start_date:
        filters.append(('filing_date', '>=', start_date))
    if end_date:
        filters.append(('filing_date', '<=', end_date))
    
    df = process_s3_partition(
        storage_provider, 
        base_path, 
        identifier_column=identifier_column, 
        identifier_values=identifiers, 
        columns=columns, 
        filters=filters
    )
    
    # if 'filing_date' in df.columns:
    #     df['date'] = pd.to_datetime(df['filing_date'])  # Ensure 'date' column exists
    # elif 'date' not in df.columns:
    #     raise ValueError("Neither 'filing_date' nor 'date' column found in the data")
    
    # df.set_index([identifier_column, 'date'], inplace=True)
    # df.sort_index(inplace=True)
    
    return df

# Example usage
config = {
    "s3": True,
    "storage_provider": {
        "digitalocean": "sovai/sovai-filings/tenk",
        "wasabi": "sovai-filings/tenk"
    },
    "identifier_column": "cik"
}
identifiers = ["1018724", "1045810"]  # Example CIKs
columns = None
start_date = "2020-01-01"
end_date = None

# %%
# %%timeit
result = client_side_s3_frame(config, identifiers, columns, start_date, end_date)
# Out:
# 6.03 s ± 93.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
result.sort_index()
# Out:
#                    ticker filing_date         company      accession_number  \
# cik     date
# 1018724 2020-01-31   AMZN  2020-01-31  AMAZON COM INC  0001018724-20-000004
#         2020-01-31   AMZN  2020-01-31  AMAZON COM INC  0001018724-20-000004
#         2020-01-31   AMZN  2020-01-31  AMAZON COM INC  0001018724-20-000004
#         2020-01-31   AMZN  2020-01-31  AMAZON COM INC  0001018724-20-000004
#         2020-01-31   AMZN  2020-01-31  AMAZON COM INC  0001018724-20-000004
# ...                   ...         ...             ...                   ...
# 1045810 2024-02-21   NVDA  2024-02-21     NVIDIA CORP  0001045810-24-000029
#         2024-02-21   NVDA  2024-02-21     NVIDIA CORP  0001045810-24-000029
#         2024-02-21   NVDA  2024-02-21     NVIDIA CORP  0001045810-24-000029
#         2024-02-21   NVDA  2024-02-21     NVIDIA CORP  0001045810-24-000029
#         2024-02-21   NVDA  2024-02-21     NVIDIA CORP  0001045810-24-000029
#
#                          section  order       category   tag  \
# cik     date
# 1018724 2020-01-31      BUSINESS      0       ListItem    tr
#         2020-01-31      BUSINESS      1       ListItem    tr
#         2020-01-31      BUSINESS      2       ListItem    tr
#         2020-01-31      BUSINESS      3       ListItem    tr
#         2020-01-31  RISK_FACTORS      0  NarrativeText  span
# ...                          ...    ...            ...   ...
# 1045810 2024-02-21      EXHIBITS    266  NarrativeText    td
#         2024-02-21      EXHIBITS    267       ListItem   div
#         2024-02-21      EXHIBITS    268  NarrativeText  span
#         2024-02-21      EXHIBITS    269  NarrativeText  span
#         2024-02-21      EXHIBITS    270  NarrativeText  span
#
#                                               row_id  \
# cik     date
# 1018724 2020-01-31  3c4bd72c4d6bebeb1f5609569195e70d
#         2020-01-31  e25e656c6ec03dec8a88139d51b5ec0a
#         2020-01-31  a234ee7a6b51299fe02da325175b757c
#         2020-01-31  1ee8c27f1a67125f5c883d4ea357c510
#         2020-01-31  e498be326c91904ee28a6e553d729407
# ...                                              ...
# 1045810 2024-02-21  7edd1e47092085a992221c107eda0e08
#         2024-02-21  ef53ee4dc7ffe7c040bd5ee7233a9778
#         2024-02-21  9b8e9e47a1be19a338ab2141b66e2cfe
#         2024-02-21  de3b672614c78814d4a3f6ab8e5adc88
#         2024-02-21  a2432559cb9f0e6f3b3a48300a90c23e
#
#                                                             full_text
# cik     date
# 1018724 2020-01-31  limitations on the repatriation and investment...
#         2020-01-31  limited fulfillment and technology infrastruct...
#         2020-01-31  shorter payable and longer receivable cycles a...
#         2020-01-31  laws and regulations regarding consumer and da...
#         2020-01-31  Please carefully consider the following discus...
# ...                                                               ...
# 1045810 2024-02-21     Power of Attorney (included in signature page)
#         2024-02-21                                    Filed herewith.
#         2024-02-21  # In accordance with Item 601(b)(32)(ii) of Re...
#         2024-02-21  ^ Certain exhibits and schedules have been omi...
#         2024-02-21  Copies of above exhibits not contained herein ...
#
# [5455 rows x 10 columns]

# %%
s3fs_object = authentication.get_s3_filesystem_pickle("digitalocean",verbose=True)

# %%
import pyarrow.dataset as ds
from pyarrow.fs import S3FileSystem
import pyarrow as pa
import pandas as pd
from functools import lru_cache

@lru_cache(maxsize=2)  # Cache the last 2 S3FileSystem objects (one for each provider)
def get_cached_s3_filesystem(storage_provider):
    return authentication.get_s3_filesystem_pickle(storage_provider, verbose=True)

def process_partition(storage_provider, cik=None, columns=None, filters=None):
    s3 = get_cached_s3_filesystem(storage_provider)
    
    if storage_provider.lower() == 'digitalocean':
        base_path = "sovai/sovai-filings/tenk"
    else:  # Wasabi
        base_path = "sovai-filings/tenk"
    
    if cik:
        base_path += f"/cik={cik}"
    
    dataset = ds.dataset(base_path, filesystem=s3, format='parquet')
    
    if filters:
        operator_map = {
            '==': lambda a, b: a == b,
            '!=': lambda a, b: a != b,
            '<': lambda a, b: a < b,
            '<=': lambda a, b: a <= b,
            '>': lambda a, b: a > b,
            '>=': lambda a, b: a >= b,
            'in': lambda a, b: a.isin(b),
            'not in': lambda a, b: ~a.isin(b),
            'like': lambda a, b: a.match_substring(b),
        }
        schema = dataset.schema
        filter_expr = None
        for col, op, val in filters:
            if op not in operator_map:
                raise ValueError(f"Unsupported operator '{op}' in filters.")
            field = ds.field(col)
            field_type = schema.field(col).type
            # Convert the value to the appropriate type based on the column type
            if pa.types.is_timestamp(field_type) or pa.types.is_date(field_type):
                val = pd.to_datetime(val)
            elif pa.types.is_integer(field_type):
                val = int(val)
            elif pa.types.is_floating(field_type):
                val = float(val)
            # For string and other types, keep the value as is
            condition = operator_map[op](field, val)
            filter_expr = condition if filter_expr is None else filter_expr & condition
    else:
        filter_expr = None
    
    table = dataset.to_table(columns=columns, filter=filter_expr, use_threads=True)
    return table.to_pandas(use_threads=True)

# Example usage
storage_provider = 'wasabi'  # or 'wasabi'
cik = 1018724
columns = None
filters = [('filing_date', '>=', '2020-01-01')]
final_df = process_partition(storage_provider, cik, columns, filters)

# %%
# %%timeit
final_df = process_partition(storage_provider, cik, columns, filters)
# Out:
# 598 ms ± 27.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Example usage
storage_provider = 'digitalocean'
cik = 1018724
columns = None
filters = [('filing_date', '>=', '2020-01-01')]

# %%
# %%timeit
final_df = process_partition(storage_provider, cik, columns, filters)
# Out:
# 375 ms ± 10.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
process_partition('wasabi', cik, columns, filters)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 process_partition('wasabi', cik, columns, filters)
#
# Cell In[14], line 17, in process_partition(storage_provider, cik, columns, filters)
#      14 if cik:
#      15     base_path += f"/cik={cik}"
# ---> 17 dataset = ds.dataset(base_path, filesystem=s3, format='parquet')
#      19 if filters:
#      20     operator_map = {
#      21         '==': lambda a, b: a == b,
#      22         '!=': lambda a, b: a != b,
#    (...)
#      29         'like': lambda a, b: a.match_substring(b),
#      30     }
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/pyarrow/dataset.py:794, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     783 kwargs = dict(
#     784     schema=schema,
#     785     filesystem=filesystem,
#    (...)
#     790     selector_ignore_prefixes=ignore_prefixes
#     791 )
#     793 if _is_path_like(source):
# --> 794     return _filesystem_dataset(source, **kwargs)
#     795 elif isinstance(source, (tuple, list)):
#     796     if all(_is_path_like(elem) or isinstance(elem, FileInfo) for elem in source):
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/pyarrow/dataset.py:476, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     474         fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     475 else:
# --> 476     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     478 options = FileSystemFactoryOptions(
#     479     partitioning=partitioning,
#     480     partition_base_dir=partition_base_dir,
#     481     exclude_invalid_files=exclude_invalid_files,
#     482     selector_ignore_prefixes=selector_ignore_prefixes
#     483 )
#     484 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/pyarrow/dataset.py:441, in _ensure_single_source(path, filesystem)
#     439     paths_or_selector = [path]
#     440 else:
# --> 441     raise FileNotFoundError(path)
#     443 return filesystem, paths_or_selector
#
# FileNotFoundError: sovai/tenk/cik=1018724

# %%
# %%timeit
final_df = process_partition('wasabi', cik, columns, filters)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_ipython().run_cell_magic('timeit', '', "final_df = process_partition('wasabi', cik, columns, filters)\n")
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/IPython/core/magics/execution.py:1185, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1183 for index in range(0, 10):
#    1184     number = 10 ** index
# -> 1185     time_number = timer.timeit(number)
#    1186     if time_number >= 0.2:
#    1187         break
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# Cell In[14], line 17, in process_partition(storage_provider, cik, columns, filters)
#      14 if cik:
#      15     base_path += f"/cik={cik}"
# ---> 17 dataset = ds.dataset(base_path, filesystem=s3, format='parquet')
#      19 if filters:
#      20     operator_map = {
#      21         '==': lambda a, b: a == b,
#      22         '!=': lambda a, b: a != b,
#    (...)
#      29         'like': lambda a, b: a.match_substring(b),
#      30     }
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/pyarrow/dataset.py:794, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     783 kwargs = dict(
#     784     schema=schema,
#     785     filesystem=filesystem,
#    (...)
#     790     selector_ignore_prefixes=ignore_prefixes
#     791 )
#     793 if _is_path_like(source):
# --> 794     return _filesystem_dataset(source, **kwargs)
#     795 elif isinstance(source, (tuple, list)):
#     796     if all(_is_path_like(elem) or isinstance(elem, FileInfo) for elem in source):
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/pyarrow/dataset.py:476, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     474         fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     475 else:
# --> 476     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     478 options = FileSystemFactoryOptions(
#     479     partitioning=partitioning,
#     480     partition_base_dir=partition_base_dir,
#     481     exclude_invalid_files=exclude_invalid_files,
#     482     selector_ignore_prefixes=selector_ignore_prefixes
#     483 )
#     484 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#
# File ~/Sovai/GitHub/SovAI/.venv/lib/python3.11/site-packages/pyarrow/dataset.py:441, in _ensure_single_source(path, filesystem)
#     439     paths_or_selector = [path]
#     440 else:
# --> 441     raise FileNotFoundError(path)
#     443 return filesystem, paths_or_selector
#
# FileNotFoundError: sovai/tenk/cik=1018724

# %%
final_df
# Out:
#      ticker filing_date         company      cik      accession_number  \
# 0      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 1      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 2      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 3      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 4      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# ...     ...         ...             ...      ...                   ...
# 3400   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3401   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3402   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3403   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3404   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
#
#            section  order       category   tag  \
# 0         BUSINESS      0       ListItem    tr
# 1         BUSINESS      1       ListItem    tr
# 2         BUSINESS      2       ListItem    tr
# 3         BUSINESS      3       ListItem    tr
# 4     RISK_FACTORS      0  NarrativeText  span
# ...            ...    ...            ...   ...
# 3400      EXHIBITS     11  NarrativeText    td
# 3401      EXHIBITS     12  NarrativeText    td
# 3402      EXHIBITS     13  NarrativeText    td
# 3403      EXHIBITS     14  NarrativeText    td
# 3404      EXHIBITS     15  NarrativeText    td
#
#                                 row_id  \
# 0     3c4bd72c4d6bebeb1f5609569195e70d
# 1     e25e656c6ec03dec8a88139d51b5ec0a
# 2     a234ee7a6b51299fe02da325175b757c
# 3     1ee8c27f1a67125f5c883d4ea357c510
# 4     e498be326c91904ee28a6e553d729407
# ...                                ...
# 3400  6e10005c9c5f296a4508772bfbd1b6e6
# 3401  9d7eb61ac35b6e8db69e310ff94bc022
# 3402  031fa93d31812a8a247bf7201f2dcbbc
# 3403  ce9cac19ce2ee676a5272d9ba1ac67e9
# 3404  88e11504afc87ab227540414cba9508b
#
#                                               full_text
# 0     limitations on the repatriation and investment...
# 1     limited fulfillment and technology infrastruct...
# 2     shorter payable and longer receivable cycles a...
# 3     laws and regulations regarding consumer and da...
# 4     Please carefully consider the following discus...
# ...                                                 ...
# 3400  Form of Indemnification Agreement between Amaz...
# 3401  Term Loan Agreement, dated as of January 3, 20...
# 3402  Five-Year Revolving Credit Agreement, dated as...
# 3403  364-Day Revolving Credit Agreement, dated as o...
# 3404  As permitted by Item 601(b)(4)(iii)(A) of Regu...
#
# [3405 rows x 11 columns]

# %%
import pyarrow.dataset as ds
from pyarrow.fs import S3FileSystem
import pyarrow as pa
import pandas as pd


storage_provider = 'digitalocean'
cik = '1018724'
# cik= None
columns = None
# filters = [('filing_date', '>=', '2020-01-01')]


s3 = s3fs_object

base_path = f"sovai/{'sovai-filings/' if storage_provider.lower() == 'digitalocean' else ''}tenk"
if cik:
    base_path += f"/cik={cik}"

dataset = ds.dataset(base_path, filesystem=s3, format='parquet')

if filters:
    operator_map = {
        '==': lambda a, b: a == b,
        '!=': lambda a, b: a != b,
        '<': lambda a, b: a < b,
        '<=': lambda a, b: a <= b,
        '>': lambda a, b: a > b,
        '>=': lambda a, b: a >= b,
        'in': lambda a, b: a.isin(b),
        'not in': lambda a, b: ~a.isin(b),
        'like': lambda a, b: a.match_substring(b),
    }

    schema = dataset.schema

    filter_expr = None
    for col, op, val in filters:
        if op not in operator_map:
            raise ValueError(f"Unsupported operator '{op}' in filters.")

        field = ds.field(col)
        field_type = schema.field(col).type

        # Convert the value to the appropriate type based on the column type
        if pa.types.is_timestamp(field_type) or pa.types.is_date(field_type):
            val = pd.to_datetime(val)
        elif pa.types.is_integer(field_type):
            val = int(val)
        elif pa.types.is_floating(field_type):
            val = float(val)
        # For string and other types, keep the value as is

        condition = operator_map[op](field, val)
        filter_expr = condition if filter_expr is None else filter_expr & condition
else:
    filter_expr = None

table = dataset.to_table(columns=columns, filter=filter_expr, use_threads=True).to_pandas()

# %%
table
# Out:
#      ticker filing_date         company      cik      accession_number  \
# 0      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 1      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 2      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 3      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# 4      AMZN  2020-01-31  AMAZON COM INC  1018724  0001018724-20-000004
# ...     ...         ...             ...      ...                   ...
# 3400   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3401   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3402   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3403   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
# 3404   AMZN  2024-02-02  AMAZON COM INC  1018724  0001018724-24-000008
#
#            section  order       category   tag  \
# 0         BUSINESS      0       ListItem    tr
# 1         BUSINESS      1       ListItem    tr
# 2         BUSINESS      2       ListItem    tr
# 3         BUSINESS      3       ListItem    tr
# 4     RISK_FACTORS      0  NarrativeText  span
# ...            ...    ...            ...   ...
# 3400      EXHIBITS     11  NarrativeText    td
# 3401      EXHIBITS     12  NarrativeText    td
# 3402      EXHIBITS     13  NarrativeText    td
# 3403      EXHIBITS     14  NarrativeText    td
# 3404      EXHIBITS     15  NarrativeText    td
#
#                                 row_id  \
# 0     3c4bd72c4d6bebeb1f5609569195e70d
# 1     e25e656c6ec03dec8a88139d51b5ec0a
# 2     a234ee7a6b51299fe02da325175b757c
# 3     1ee8c27f1a67125f5c883d4ea357c510
# 4     e498be326c91904ee28a6e553d729407
# ...                                ...
# 3400  6e10005c9c5f296a4508772bfbd1b6e6
# 3401  9d7eb61ac35b6e8db69e310ff94bc022
# 3402  031fa93d31812a8a247bf7201f2dcbbc
# 3403  ce9cac19ce2ee676a5272d9ba1ac67e9
# 3404  88e11504afc87ab227540414cba9508b
#
#                                               full_text
# 0     limitations on the repatriation and investment...
# 1     limited fulfillment and technology infrastruct...
# 2     shorter payable and longer receivable cycles a...
# 3     laws and regulations regarding consumer and da...
# 4     Please carefully consider the following discus...
# ...                                                 ...
# 3400  Form of Indemnification Agreement between Amaz...
# 3401  Term Loan Agreement, dated as of January 3, 20...
# 3402  Five-Year Revolving Credit Agreement, dated as...
# 3403  364-Day Revolving Credit Agreement, dated as o...
# 3404  As permitted by Item 601(b)(4)(iii)(A) of Regu...
#
# [3405 rows x 11 columns]

# %%
import pyarrow.dataset as ds
from pyarrow.fs import S3FileSystem
import pyarrow as pa
import pandas as pd

def get_s3_filesystem(storage_provider):
    credentials = {
        'wasabi': {
            'endpoint': 'https://s3.wasabisys.com',
                'access_key': 'KI07G4DK9XP5EC0NH1VU',
                'secret_key': 'kXLnJylZJ4aiDuA5BtbEq9N53C1eFUmyVqsnCzRn'
        },
        'digitalocean': {
            'endpoint': 'https://nyc3.digitaloceanspaces.com',
            'access_key': 'DO00U3NVRFE2P83JPDU2',
            'secret_key': 'AuYt4sW4F02yR+ERhtg0n9dGX2Qk5xaLtZTUY+V+yQo'
        }
    }

    cred = credentials.get(storage_provider.lower())
    if not cred:
        raise ValueError("Invalid storage provider. Choose 'wasabi' or 'digitalocean'.")

    return S3FileSystem(access_key=cred['access_key'],
                        secret_key=cred['secret_key'],
                        endpoint_override=cred['endpoint'])

def process_partition(storage_provider, cik=None, columns=None, filters=None):
    s3 = get_s3_filesystem(storage_provider)
    base_path = f"sovai/{'sovai-filings/' if storage_provider.lower() == 'digitalocean' else ''}tenk"
    if cik:
        base_path += f"/cik={cik}"

    dataset = ds.dataset(base_path, filesystem=s3, format='parquet')

    if filters:
        operator_map = {
            '==': lambda a, b: a == b,
            '!=': lambda a, b: a != b,
            '<': lambda a, b: a < b,
            '<=': lambda a, b: a <= b,
            '>': lambda a, b: a > b,
            '>=': lambda a, b: a >= b,
            'in': lambda a, b: a.isin(b),
            'not in': lambda a, b: ~a.isin(b),
            'like': lambda a, b: a.match_substring(b),
        }

        schema = dataset.schema

        filter_expr = None
        for col, op, val in filters:
            if op not in operator_map:
                raise ValueError(f"Unsupported operator '{op}' in filters.")

            field = ds.field(col)
            field_type = schema.field(col).type

            # Convert the value to the appropriate type based on the column type
            if pa.types.is_timestamp(field_type) or pa.types.is_date(field_type):
                val = pd.to_datetime(val)
            elif pa.types.is_integer(field_type):
                val = int(val)
            elif pa.types.is_floating(field_type):
                val = float(val)
            # For string and other types, keep the value as is

            condition = operator_map[op](field, val)
            filter_expr = condition if filter_expr is None else filter_expr & condition
    else:
        filter_expr = None

    table = dataset.to_table(columns=columns, filter=filter_expr, use_threads=True)
    return table.to_pandas(use_threads=True)

# Example usage
storage_provider = 'digitalocean'
cik = '1018724'
cik= None
columns = None
filters = [('filing_date', '>=', '2020-01-01')]

final_df = process_partition(storage_provider, cik, columns, filters)
# Out:
# NoneType
