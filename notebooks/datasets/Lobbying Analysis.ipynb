# %%
# !pip install sovai[full]

# %% [markdown]
# ## Lobbying Analysis

# %%
import sovai as sov
sov.token_auth(token="visit https://sov.ai/profile for your token")

# %% [markdown]
# #### Processed Dataset

# %%
df_lobbying = sov.data("lobbying/public/", tickers=["WFC","EXPGY","AAPL"])

# %%
df_lobbying.sort_values("date")
# Out:
#                    index                 client  \
# ticker date
# AAPL   2001-07-02    474                  apple
#        2001-07-02    475                  apple
# WFC    2007-08-13      1  wells fargo & company
#        2007-08-13      0  wells fargo & company
# AAPL   2007-08-14    478              apple inc
# ...                  ...                    ...
#        2024-07-22    796             apple inc.
#        2024-07-22    797             apple inc.
#        2024-07-22    798             apple inc.
#        2024-07-22    794              apple inc
# WFC    2024-08-16    411  wells fargo & company
#
#                                                   client_description  \
# ticker date
# AAPL   2001-07-02                                               None
#        2001-07-02                                               None
# WFC    2007-08-13                                               None
#        2007-08-13                                               None
# ...
